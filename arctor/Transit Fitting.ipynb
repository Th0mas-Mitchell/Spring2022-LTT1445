# %%
import time
start_time = time.time()
import os
HOME = os.environ['HOME']
# os.chdir(f'{HOME}/desktop/LTT1445_fits_files/Test/Tes2')
os.chdir(f'{HOME}/desktop/LTT1445_fits_files/Test/Tes2/Tes3')

# %%
import joblib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.stats import mad_std, sigma_clip
import warnings
warnings.filterwarnings("ignore")

import exoplanet as xo

from ArctorTesting import Arctor, info_message

# %%
def instantiate_arctor(planet_name, data_dir, working_dir, file_type):
    planet = Arctor(
        planet_name=planet_name,
        data_dir=data_dir,
        working_dir=working_dir,
        file_type=file_type)

    joblib_filename = f'{planet_name}_savedict.joblib.save'
    joblib_filename = f'{working_dir}/{joblib_filename}'
    if os.path.exists(joblib_filename):
        info_message('Loading Data from Save File')
        planet.load_data(joblib_filename)
    else:
        info_message('Loading New Data Object')
        planet.load_data()

    return planet

def create_raw_lc_stddev(planet):
    ppm = 1e6
    phot_vals = planet.photometry_df
    lc_std_rev = phot_vals.iloc[planet.idx_rev].std(axis=0)                
    lc_std_fwd = phot_vals.iloc[planet.idx_fwd].std(axis=0)                

    lc_med_rev = np.median(phot_vals.iloc[planet.idx_rev], axis=0)
    lc_med_fwd = np.median(phot_vals.iloc[planet.idx_rev], axis=0)

    lc_std = np.mean([lc_std_rev, lc_std_fwd], axis=0)
    lc_med = np.mean([lc_med_rev, lc_med_fwd], axis=0)

    return lc_std / lc_med * ppm

# %%
plot_verbose = False
save_now = False
planet_name = 'PlanetName'
file_type = 'flt.fits'

HOME = os.environ['HOME']
# base_dir = os.path.join(HOME, 'path', 'to', 'base')
# data_dir = os.path.join(base_dir, 'path', 'to', 'data')
# data_dir = os.path.join(data_dir, 'HST', 'FLTs')
# working_dir = os.path.join(base_dir, 'path', 'to', 'savefiles')
base_dir = os.path.join(HOME, 'desktop', 'LTT1445_fits_files', 'Test', 'Tes2', 'Tes3')
data_dir = os.path.join(base_dir)
data_dir = os.path.join(data_dir)
working_dir = os.path.join(base_dir)

# %%
planet = instantiate_arctor(planet_name, data_dir, working_dir, file_type)
print(planet)
# Out:
# [INFO] Initializing Instance of the `Arctor` Object
# [INFO] Loading New Data Object
# [INFO] Loading Fits Files
# 100%|██████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 296.87it/s]
# [INFO] Creating New Flux/Error/Time Attributes
#  13%|██████████▍                                                                       | 12/94 [00:00<00:00, 107.86it/s]
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
#  35%|█████████████████████████████▏                                                     | 33/94 [00:00<00:00, 92.50it/s]
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
#  56%|██████████████████████████████████████████████▊                                    | 53/94 [00:00<00:00, 90.99it/s]
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
#  67%|███████████████████████████████████████████████████████▋                           | 63/94 [00:00<00:00, 90.95it/s]
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
#  78%|████████████████████████████████████████████████████████████████▍                  | 73/94 [00:00<00:00, 82.30it/s]
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
#  87%|████████████████████████████████████████████████████████████████████████▍          | 82/94 [00:00<00:00, 72.41it/s]
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# 100%|███████████████████████████████████████████████████████████████████████████████████| 94/94 [00:01<00:00, 85.14it/s]
# image_shape (512, 513)
# image_shape (512, 513)
# image_shape (512, 513)
# [INFO] Found 94 flt.fits files
# <ArctorTesting.Arctor object at 0x7f155fc239a0>

# %%
planet.clean_cosmic_rays()
planet.calibration_trace_location()
planet.identify_trace_direction()
planet.simple_phots()
planet.center_all_traces()
planet.fit_trace_slopes()
planet.compute_sky_background(subpixels=32)
planet.compute_columnwise_sky_background()
# Out:
# [INFO] Flagging Cosmic Rays using `Temporal Simple` Technique
# 100%|█████████████████████████████████████████████████████████████████████████████████| 513/513 [00:20<00:00, 24.49it/s]
# [INFO] Cosmic Ray Mask Creation Took 20.952035188674927 seconds
# None
# [INFO] Calibration the Median Trace Location
# [INFO] Cubic Spline Interpolating the Median Trace Location
# [INFO] Calibration the Per Image Trace Location
# 100%|██████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 455.59it/s]
# [INFO] Identifying Trace Direction per Image
# 100%|██████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 348.10it/s]
# [INFO] Computing the Center of the Trace
# 100%|███████████████████████████████████████████████████████████████████████████████████| 94/94 [01:30<00:00,  1.04it/s]
# [INFO] Fitting a slope to the Center of the Trace
# 100%|███████████████████████████████████████████████████████████████████████████████████| 94/94 [01:14<00:00,  1.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 94/94 [00:01<00:00, 76.09it/s]

# %%
# Set up the list of aperture widths and heights to search
min_aper_width = 1
max_aper_width = 100
min_aper_height = 1
max_aper_height = 100

aper_widths = np.arange(min_aper_width, max_aper_width + 2, 5)
aper_heights = np.arange(min_aper_height, max_aper_height + 2, 5)

# %%
planet.do_multi_phot(aper_widths, aper_heights)
print("code took", (time.time()-start_time)/60, "minutes")
# Out:
# [INFO] Beginning Multi-Aperture Photometry
# [253.30493772 263.87014367 253.46494084 262.96012593 255.13997349
#  261.35009454 254.89496871 260.24007291 255.15997388 259.81006452
#  255.07997232 266.58519659 254.9149691  259.51505877 255.01497105
#  262.29511297 253.85494844 260.54007875 252.99993177 263.09512856
#  253.82494785 261.93510595 254.9199692  262.43511569 252.68492563
#  263.77514182 255.01497105 263.10512875 253.1349344  264.02014659
#  252.78992768 260.26507339 255.21997505 260.15507125 253.41493986
#  263.25013158 252.96993119 262.37011443 253.50994171 260.35507515
#  253.56994288 260.36507534 252.46492134 260.47007739 255.25497573
#  259.36505585 252.82492836 260.30007408 252.43992086 259.49005829
#  254.90496891 262.20511121 255.69998441 260.30507417 252.04491316
#  260.96508704 258.0750307  260.16507144 256.57000136 263.10512875
#  252.91993021 260.82508431 253.09993372 263.70514045 256.66000312
#  263.0201271  252.86492914 262.77012222 254.95496988 259.77006374
#  253.26993704 260.450077   253.23993645 263.63513909 253.26993704
#  263.12012905 252.71492622 261.80510341 253.89994932 263.04012749
#  253.18993548 261.89510517 254.78996667 259.6650617  254.30495721
#  272.90531979 259.8550654  263.74014113 255.10497281 284.39054368
#  256.56000117 263.88014386 255.7199848  263.70014035] [329.42505107 326.95643732 329.40205332 326.93545651 329.81803164
#  326.51799449 329.38309742 326.48843507 329.38555618 326.48854345
#  329.35329202 326.47310095 329.77282521 326.88358987 329.34451187
#  326.46312348 329.76767326 326.46351759 329.35076914 326.46602903
#  329.41240324 326.48605655 329.34783864 326.46860621 329.36672039
#  326.47467248 329.3749786  327.32321383 329.40361434 326.46968718
#  329.45409976 326.96856938 329.44108344 326.96399074 329.77518042
#  326.55599708 329.42809411 326.53859055 329.4144255  326.92100531
#  329.80218414 326.46977977 329.39492828 327.32434452 329.38162772
#  326.8826313  329.3571063  326.47219055 329.35701777 326.86928774
#  329.35282618 326.46943513 329.3044049  326.48575994 329.37759316
#  326.48264938 329.37084509 326.48033196 329.39187955 326.49206871
#  329.38324361 326.91627947 329.43478679 326.54074203 329.47863473
#  326.53661616 329.40397134 326.93737917 329.81452707 326.5026013
#  329.37163561 326.52325612 329.35888983 326.92434298 330.20589453
#  326.47652832 329.3555384  326.48772664 329.35400906 326.46172442
#  329.36320276 326.89037966 329.35162374 326.45874181 329.3658588
#  326.89419764 329.35767039 326.45529138 329.36205658 326.47580858
#  329.39330267 326.48747244 329.37058934 326.50209532] [[253.30493772 329.42505107]
#  [263.87014367 326.95643732]
#  [253.46494084 329.40205332]
#  [262.96012593 326.93545651]
#  [255.13997349 329.81803164]
#  [261.35009454 326.51799449]
#  [254.89496871 329.38309742]
#  [260.24007291 326.48843507]
#  [255.15997388 329.38555618]
#  [259.81006452 326.48854345]
#  [255.07997232 329.35329202]
#  [266.58519659 326.47310095]
#  [254.9149691  329.77282521]
#  [259.51505877 326.88358987]
#  [255.01497105 329.34451187]
#  [262.29511297 326.46312348]
#  [253.85494844 329.76767326]
#  [260.54007875 326.46351759]
#  [252.99993177 329.35076914]
#  [263.09512856 326.46602903]
#  [253.82494785 329.41240324]
#  [261.93510595 326.48605655]
#  [254.9199692  329.34783864]
#  [262.43511569 326.46860621]
#  [252.68492563 329.36672039]
#  [263.77514182 326.47467248]
#  [255.01497105 329.3749786 ]
#  [263.10512875 327.32321383]
#  [253.1349344  329.40361434]
#  [264.02014659 326.46968718]
#  [252.78992768 329.45409976]
#  [260.26507339 326.96856938]
#  [255.21997505 329.44108344]
#  [260.15507125 326.96399074]
#  [253.41493986 329.77518042]
#  [263.25013158 326.55599708]
#  [252.96993119 329.42809411]
#  [262.37011443 326.53859055]
#  [253.50994171 329.4144255 ]
#  [260.35507515 326.92100531]
#  [253.56994288 329.80218414]
#  [260.36507534 326.46977977]
#  [252.46492134 329.39492828]
#  [260.47007739 327.32434452]
#  [255.25497573 329.38162772]
#  [259.36505585 326.8826313 ]
#  [252.82492836 329.3571063 ]
#  [260.30007408 326.47219055]
#  [252.43992086 329.35701777]
#  [259.49005829 326.86928774]
#  [254.90496891 329.35282618]
#  [262.20511121 326.46943513]
#  [255.69998441 329.3044049 ]
#  [260.30507417 326.48575994]
#  [252.04491316 329.37759316]
#  [260.96508704 326.48264938]
#  [258.0750307  329.37084509]
#  [260.16507144 326.48033196]
#  [256.57000136 329.39187955]
#  [263.10512875 326.49206871]
#  [252.91993021 329.38324361]
#  [260.82508431 326.91627947]
#  [253.09993372 329.43478679]
#  [263.70514045 326.54074203]
#  [256.66000312 329.47863473]
#  [263.0201271  326.53661616]
#  [252.86492914 329.40397134]
#  [262.77012222 326.93737917]
#  [254.95496988 329.81452707]
#  [259.77006374 326.5026013 ]
#  [253.26993704 329.37163561]
#  [260.450077   326.52325612]
#  [253.23993645 329.35888983]
#  [263.63513909 326.92434298]
#  [253.26993704 330.20589453]
#  [263.12012905 326.47652832]
#  [252.71492622 329.3555384 ]
#  [261.80510341 326.48772664]
#  [253.89994932 329.35400906]
#  [263.04012749 326.46172442]
#  [253.18993548 329.36320276]
#  [261.89510517 326.89037966]
#  [254.78996667 329.35162374]
#  [259.6650617  326.45874181]
#  [254.30495721 329.3658588 ]
#  [272.90531979 326.89419764]
#  [259.8550654  329.35767039]
#  [263.74014113 326.45529138]
#  [255.10497281 329.36205658]
#  [284.39054368 326.47580858]
#  [256.56000117 329.39330267]
#  [263.88014386 326.48747244]
#  [255.7199848  329.37058934]
#  [263.70014035 326.50209532]]
# [INFO] Creating Apertures
# 100%|██████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 148.94it/s]
# [INFO] Configuing Photoutils.Aperture_Photometry
# [INFO] Computing Aperture Photometry per Image
# done 1
# <multiprocessing.pool.Pool state=RUN pool_size=7>
# done 2
# [<QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64           float64
# ----- ------------------ ---------------- ----------------- ... ----------------- ----------------- -----------------
#     1 253.30493771808415 329.425051070842 549091.9408462578 ... 51570651.64684069 51935300.90751378 52299593.52959271, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0   ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64           float64       ...      float64           float64           float64
# ----- ----------------- ----------------- ------------------ ... ------------------ ---------------- ------------------
#     1 263.8701436675179 326.9564373235543 482911.75679313485 ... 48958554.200389884 49303711.6539091 49623976.771933354, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438 aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64          float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ---------------- -----------------
#     1 253.46494083705335 329.4020533155685 535707.8560107425 ... 51593251.99764259  51953415.892769 52318067.70461278, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix         ...
# int64      float64            float64       ...      float64           float64            float64
# ----- ------------------ ------------------ ... ----------------- ------------------ ------------------
#     1 262.96012592838065 326.93545651468276 ... 48983557.09568801 49328077.216585584 49648122.392476514, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64            float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ------------------ -----------------
#     1 255.13997348876194 329.8180316400627 555513.1924161485 ... 52050119.97726004 52416063.986794196 52774339.77475771, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0   ...  aperture_sum_438  aperture_sum_439 aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64           float64       ...      float64           float64          float64
# ----- ----------------- ----------------- ------------------ ... ----------------- ----------------- ----------------
#     1 261.3500945437533 326.5179944856611 444854.37059357157 ... 48568046.62085848 48904343.77275543 49185588.6241581, <QTable length=1>
#   id       xcenter          ycenter        aperture_sum_0  ... aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix              pix                          ...
# int64      float64          float64           float64      ...     float64           float64           float64
# ----- ----------------- ---------------- ----------------- ... ---------------- ----------------- ------------------
#     1 254.8949687128404 329.383097421958 553752.0827917629 ... 51652155.8870225 52017409.92089911 52378599.525020726, <QTable length=1>
#   id       xcenter           ycenter       ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix               pix         ...
# int64      float64           float64       ...      float64            float64           float64
# ----- ----------------- ------------------ ... ------------------ ----------------- ------------------
#     1 260.2400729059046 326.48843506912397 ... 48559415.482992254 48889479.99802334 49168093.335951544, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64            float64           float64
# ----- ----------------- ----------------- ----------------- ... ------------------ ----------------- -----------------
#     1 255.1599738786331 329.3855561764192 550348.0783930547 ... 51624786.231680706 51987031.11496675 52348968.55988425, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0   ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64           float64       ...      float64           float64           float64
# ----- ----------------- ----------------- ------------------ ... ----------------- ----------------- -----------------
#     1 259.8100645236749 326.4885434541649 451388.66840010416 ... 48524489.04317346 48863692.07738621 49150715.90059616, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438 aperture_sum_439  aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64          float64           float64
# ----- ----------------- ----------------- ----------------- ... ----------------- ---------------- ------------------
#     1 255.0799723191485 329.3532920229721 544706.3964287727 ... 51595498.94545086 51959217.1897064 52323096.678042166, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- ------------------
#     1 266.58519659252613 326.4731009494542 469814.2543190876 ... 48662626.52101158 48971429.28687409 49215219.100398876, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64            float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ------------------ -----------------
#     1 254.91496910271155 329.7728252105946 538927.6459511695 ... 52022793.39436449 52389895.563434295 52755800.05592926, <QTable length=1>
#   id       xcenter           ycenter       ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix               pix         ...
# int64      float64           float64       ...      float64           float64            float64
# ----- ----------------- ------------------ ... ----------------- ------------------ -----------------
#     1 259.5150587730755 326.88358987276143 ... 48883962.28501868 49237934.531974964 49562689.38105533, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_438   aperture_sum_439   aperture_sum_440
#              pix                pix        ...
# int64      float64            float64      ...      float64            float64            float64
# ----- ------------------ ----------------- ... ------------------ ------------------ -----------------
#     1 255.01497105206727 329.3445118713696 ... 51609507.938426726 51975658.107613556 52339924.63433211, <QTable length=1>
#   id      xcenter           ycenter         aperture_sum_0  ... aperture_sum_438  aperture_sum_439  aperture_sum_440
#             pix               pix                           ...
# int64     float64           float64            float64      ...     float64           float64           float64
# ----- ---------------- ------------------ ----------------- ... ---------------- ----------------- -----------------
#     1 262.295112965165 326.46312348310795 465234.9925819617 ... 48580440.8746185 48904176.62948934 49176219.15647542, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- ------------------
#     1 253.85494843954072 329.7676732615574 564430.0897537918 ... 51921100.17990091 52284599.34713127 52645722.434886895, <QTable length=1>
#   id       xcenter           ycenter       ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix               pix         ...
# int64      float64           float64       ...      float64           float64            float64
# ----- ----------------- ------------------ ... ----------------- ------------------ -----------------
#     1 260.5400787539718 326.46351759248057 ... 48535083.03839804 48864625.029251575 49151253.13796513, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- -----------------
#     1 252.99993177254916 329.3507691407899 543318.5239454721 ... 51531680.34836917 51898281.57217293 52265228.26768865, <QTable length=1>
#   id       xcenter           ycenter      ...  aperture_sum_438   aperture_sum_439   aperture_sum_440
#              pix               pix        ...
# int64      float64           float64      ...      float64            float64            float64
# ----- ----------------- ----------------- ... ------------------ ------------------ -----------------
#     1 263.0951285600109 326.4660290319205 ... 48562714.915437415 48881960.216001526 49153742.27510651, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix        ...
# int64      float64            float64      ...      float64           float64            float64
# ----- ------------------ ----------------- ... ----------------- ------------------ ------------------
#     1 253.82494785473398 329.4124032396685 ... 51583619.13523142 51947993.510740496 52307672.794865705, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ... aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...     float64           float64           float64
# ----- ----------------- ----------------- ----------------- ... ---------------- ----------------- -----------------
#     1 261.9351059474844 326.4860565472312 437487.3900262634 ... 48566635.3512867 48890711.43748957 49161820.12625762, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64           float64
# ----- ------------------ ---------------- ----------------- ... ----------------- ----------------- -----------------
#     1 254.91996920017934 329.347838643757 536914.1577732433 ... 51593755.85001542 51956096.04537974 52316494.76148446, <QTable length=1>
#   id      xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#             pix               pix                          ...
# int64     float64           float64           float64      ...      float64           float64           float64
# ----- ---------------- ----------------- ----------------- ... ----------------- ----------------- ------------------
#     1 262.435115694263 326.4686062084583 466315.4433224248 ... 48532488.48971381 48861702.70657637 49143404.993844196, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64            float64           float64
# ----- ------------------ ----------------- ----------------- ... ------------------ ----------------- -----------------
#     1 252.68492563207857 329.3667203869603 541247.7799942959 ... 51502743.026114166 51873124.77729628 52236203.82561394, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0   ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64           float64       ...      float64           float64           float64
# ----- ----------------- ----------------- ------------------ ... ----------------- ----------------- -----------------
#     1 263.7751418156299 326.4746724844748 475436.62582335295 ... 48565959.98157689 48890500.09179368 49160227.69028708, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_438   aperture_sum_439   aperture_sum_440
#              pix                pix        ...
# int64      float64            float64      ...      float64            float64            float64
# ----- ------------------ ----------------- ... ------------------ ------------------ -----------------
#     1 255.01497105206727 329.3749786038794 ... 51578007.549636066 51945921.453772746 52310493.45851663, <QTable length=1>
#   id       xcenter            ycenter       aperture_sum_0  ...  aperture_sum_438   aperture_sum_439   aperture_sum_440
#              pix                pix                         ...
# int64      float64            float64          float64      ...      float64            float64            float64
# ----- ------------------ ----------------- ---------------- ... ------------------ ------------------ -----------------
#     1 263.10512875494646 327.3232138290779 457119.637590704 ... 49350847.603343844 49706187.245936245 50043507.87637141, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64           float64
# ----- ----------------- ----------------- ----------------- ... ----------------- ------------------ ----------------
#     1 253.1349344041794 329.4036143402776 553155.0878831414 ... 51502928.89972085 51872631.631053634 52239452.4638099, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64            float64           float64
# ----- ------------------ ----------------- ----------------- ... ------------------ ----------------- -----------------
#     1 264.02014659155145 326.4696871818514 470497.9414538946 ... 48549347.260227695 48876672.39519581 49153780.50717887, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64           float64           float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 252.7899276789021 329.45409975752455 557585.8518068923 ... 51572576.75868068 51944649.33796433 52306802.44317476, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix         ...
# int64      float64            float64       ...      float64           float64           float64
# ----- ------------------ ------------------ ... ----------------- ----------------- ------------------
#     1 260.26507339324354 326.96856938289204 ... 48892141.99142323 49235330.33275985 49551305.498905525, <QTable length=1>
#   id       xcenter            ycenter         aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                           ...
# int64      float64            float64            float64      ...      float64           float64           float64
# ----- ------------------ ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 255.21997504824657 329.44108344078046 534847.3171958323 ... 51618753.74778523 51989248.88357294 52358533.68245408, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64            float64
# ----- ----------------- ----------------- ----------------- ... ----------------- ------------------ ------------------
#     1 260.1550712489522 326.9639907423599 454963.7748630401 ... 48911270.31458137 49251540.098754294 49569191.071409956, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix         ...
# int64      float64            float64       ...      float64           float64            float64
# ----- ------------------ ------------------ ... ----------------- ------------------ ------------------
#     1 253.41493986237546 329.77518041644504 ... 51918799.99289512 52289383.605405346 52651700.701935604, <QTable length=1>
#   id       xcenter           ycenter      aperture_sum_0 ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                       ...
# int64      float64           float64         float64     ...      float64           float64           float64
# ----- ----------------- ----------------- -------------- ... ----------------- ----------------- -----------------
#     1 263.2501315815123 326.5559970816038 468095.9558464 ... 48604748.76143537 48927094.96560155 49202117.58228835, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix         ...
# int64      float64            float64       ...      float64           float64           float64
# ----- ------------------ ------------------ ... ----------------- ----------------- ------------------
#     1 252.96993118774245 329.42809411228507 ... 51580795.56735633 51950993.41172698 52318562.468889974, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64           float64           float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ----------------- ------------------
#     1 262.3701144271818 326.53859054825824 460334.3436990881 ... 48586858.01005964 48911660.03993332 49192859.318979464, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix                pix        ...
# int64      float64            float64      ...      float64            float64           float64
# ----- ------------------ ----------------- ... ------------------ ----------------- ------------------
#     1 253.50994171426345 329.4144254976702 ... 51588322.086550444 51952879.66225595 52319724.512896456, <QTable length=1>
#   id       xcenter          ycenter        aperture_sum_0   ...  aperture_sum_438 aperture_sum_439  aperture_sum_440
#              pix              pix                           ...
# int64      float64          float64           float64       ...      float64          float64           float64
# ----- ----------------- ---------------- ------------------ ... ----------------- ---------------- -----------------
#     1 260.3550751476637 326.921005309694 457854.89217409864 ... 48928588.92904122 49278789.8657245 49598230.97871663, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- ------------------
#     1 253.56994288387688 329.8021841440286 551131.0343768615 ... 51961997.39715317 52325665.47987401 52687163.461810514, <QTable length=1>
#   id       xcenter            ycenter       aperture_sum_0  ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix                         ...
# int64      float64            float64          float64      ...      float64           float64            float64
# ----- ------------------ ----------------- ---------------- ... ----------------- ------------------ -----------------
#     1 260.36507534259925 326.4697797746798 460349.625113226 ... 48577022.11408157 48908022.495637454 49185706.62005046, <QTable length=1>
#   id       xcenter           ycenter       aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                         ...
# int64      float64           float64          float64      ...      float64           float64           float64
# ----- ------------------ --------------- ----------------- ... ----------------- ----------------- -----------------
#     1 252.46492134349597 329.39492827758 546979.0994904633 ... 51561647.64295721 51928060.82449123 52292268.87879611, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64           float64           float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 260.4700773894228 327.32434451900883 474075.7680554269 ... 49447764.77337012 49813684.15100615 50163517.38163754, <QTable length=1>
#   id       xcenter            ycenter       aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                         ...
# int64      float64            float64          float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ---------------- ... ----------------- ----------------- -----------------
#     1 255.25497573052104 329.3816277211552 535648.470516941 ... 51630799.17689999 52004443.20349979 52375566.41205409, <QTable length=1>
#   id       xcenter           ycenter       ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix               pix         ...
# int64      float64           float64       ...      float64            float64           float64
# ----- ----------------- ------------------ ... ------------------ ----------------- -----------------
#     1 259.3650558490419 326.88263129646776 ... 48930599.723591276 49286131.88830701 49624577.68019771, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64           float64           float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 252.8249283611766 329.35710630257853 547146.0003018184 ... 51542555.91913038 51902661.32296638 52269717.06223007, <QTable length=1>
#   id      xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#             pix               pix                          ...
# int64     float64           float64           float64      ...      float64           float64            float64
# ----- ---------------- ----------------- ----------------- ... ----------------- ------------------ ------------------
#     1 260.300074075518 326.4721905533514 445501.9390349835 ... 48519646.21037593 48853184.138762936 49136007.877513595, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64           float64
# ----- ------------------ ---------------- ----------------- ... ----------------- ----------------- ------------------
#     1 252.43992085615704 329.357017767925 538841.4606298916 ... 51544871.79715136 51920797.58163239 52288201.267544195, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- -----------------
#     1 259.49005828573655 326.8692877360934 440082.6271585019 ... 48872065.88729429 49220183.37183746 49543878.53660785, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438 aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64          float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ---------------- -----------------
#     1 254.90496890777598 329.3528261773121 559253.6494712435 ... 51607224.37920112 51964094.4219508 52314768.91356989, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_438   aperture_sum_439   aperture_sum_440
#              pix                pix         ...
# int64      float64            float64       ...      float64            float64            float64
# ----- ------------------ ------------------ ... ------------------ ------------------ -----------------
#     1 262.20511121074486 326.46943513122096 ... 48563050.981215335 48887894.229891494 49154898.05474693, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0   ... aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix                           ...
# int64      float64            float64           float64       ...     float64           float64            float64
# ----- ------------------ ----------------- ------------------ ... ---------------- ------------------ -----------------
#     1 255.69998440515408 329.3044049006583 521869.30363886757 ... 51631848.9325206 51994202.902223594 52352857.79293282, <QTable length=1>
#   id       xcenter           ycenter      ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix               pix        ...
# int64      float64           float64      ...      float64            float64           float64
# ----- ----------------- ----------------- ... ------------------ ----------------- ------------------
#     1 260.3050741729858 326.4857599387607 ... 48541733.957153894 48873312.71505627 49149004.701559626, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- -----------------
#     1 252.04491315620186 329.3775931597561 535703.6851226236 ... 51535393.82669929 51904507.71876334 52263942.61470378, <QTable length=1>
#   id       xcenter           ycenter       ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix               pix         ...
# int64      float64           float64       ...      float64           float64            float64
# ----- ----------------- ------------------ ... ----------------- ------------------ ------------------
#     1 260.9650870387337 326.48264937897085 ... 48510627.63168073 48845165.164958596 49127244.530909635, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64            float64           float64
# ----- ----------------- ------------------ ----------------- ... ------------------ ----------------- -----------------
#     1 258.0750307023529 329.37084508523793 538304.7012615895 ... 51627238.406438366 51974193.36975643 52318200.73621221, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438 aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64          float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ---------------- ------------------
#     1 260.16507144388777 326.4803319632834 453984.7619706197 ... 48495511.69554097 48837516.6350348 49136471.425066225, <QTable length=1>
#   id      xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#             pix               pix                          ...
# int64     float64           float64           float64      ...      float64            float64           float64
# ----- ---------------- ------------------ ---------------- ... ------------------ ----------------- -----------------
#     1 256.570001364549 329.39187954631944 525521.609830451 ... 51604552.300379075 51962532.01649985 52329751.01083371, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ... aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...     float64           float64           float64
# ----- ------------------ ------------------ ---------------- ... ---------------- ----------------- -----------------
#     1 263.10512875494646 326.49206870713454 470076.076770816 ... 48551763.0356127 48870036.68127106 49129847.93411988, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64           float64           float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 252.9199302130646 329.38324361070255 539694.2789648485 ... 51483412.47386959 51854097.70223864 52217433.22506854, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix                pix         ...
# int64      float64            float64       ...      float64            float64           float64
# ----- ------------------ ------------------ ... ------------------ ----------------- -----------------
#     1 260.82508430963566 326.91627947020055 ... 48974280.433691934 49321056.66953443 49649107.42810903, <QTable length=1>
#   id       xcenter          ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix              pix                          ...
# int64      float64          float64           float64      ...      float64           float64           float64
# ----- ----------------- ---------------- ----------------- ... ----------------- ------------------ ----------------
#     1 253.0999337219049 329.434786789518 541830.9355326069 ... 51525468.28324134 51892532.393927425 52261440.0021265, <QTable length=1>
#   id       xcenter           ycenter       ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix               pix         ...
# int64      float64           float64       ...      float64           float64            float64
# ----- ----------------- ------------------ ... ----------------- ------------------ -----------------
#     1 263.7051404510809 326.54074202548225 ... 48634300.59111313 48960221.864325084 49240040.79820949, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64            float64
# ----- ------------------ ------------------ ---------------- ... ----------------- ------------------ -----------------
#     1 256.66000311896914 329.47863473224317 530898.437341189 ... 51654960.61790086 52016091.176212564 52369701.76225344, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ... aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...     float64           float64           float64
# ----- ----------------- ----------------- ----------------- ... ---------------- ----------------- ------------------
#     1 263.0201270979941 326.5366161584504 464187.6181031503 ... 48595365.4393178 48920897.40957442 49201680.537801675, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- ------------------
#     1 252.86492914091892 329.4039713357102 528641.3204763351 ... 51536240.53733749 51900490.70037774 52262845.475805625, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix                pix        ...
# int64      float64            float64      ...      float64            float64           float64
# ----- ------------------ ----------------- ... ------------------ ----------------- ------------------
#     1 262.77012222460473 326.9373791746968 ... 48930685.415743835 49272379.02776024 49584624.586246796, <QTable length=1>
#   id       xcenter            ycenter         aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                           ...
# int64      float64            float64            float64      ...      float64           float64           float64
# ----- ------------------ ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 254.95496988245384 329.81452706617483 524925.9382001674 ... 52022569.62661239 52391915.86882847 52765443.61433165, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ... aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64            float64      ...     float64           float64            float64
# ----- ----------------- ------------------ ----------------- ... ---------------- ------------------ -----------------
#     1 259.7700637439326 326.50260130039993 445871.0179635729 ... 48582135.9256554 48919834.077098526 49197023.79617297, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix                pix         ...
# int64      float64            float64       ...      float64            float64           float64
# ----- ------------------ ------------------ ... ------------------ ----------------- -----------------
#     1 253.26993703580968 329.37163560618467 ... 51531943.654904306 51888938.51601288 52243639.39897766, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64            float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ------------------ -----------------
# ...
# int64      float64           float64           float64      ...      float64            float64           float64
# ----- ----------------- ----------------- ----------------- ... ------------------ ----------------- ------------------
#     1 252.7149262168853 329.3555383966257 553497.9288308006 ... 51589279.658025056 51952709.56375779 52306968.204058886, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0   ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64           float64       ...      float64            float64           float64
# ----- ----------------- ----------------- ------------------ ... ------------------ ----------------- -----------------
#     1 261.8051034133219 326.4877266382025 455574.54374886304 ... 48584108.050663434 48916446.09940288 49193988.14011192, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64           float64
# ----- ----------------- ----------------- ----------------- ... ------------------ ---------------- -----------------
#     1 253.8999493167508 329.3540090596731 538274.1180099733 ... 51588171.304420866 51947668.5427424 52318627.33859963, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64            float64           float64
# ----- ----------------- ----------------- ----------------- ... ------------------ ----------------- ------------------
#     1 263.0401274878652 326.4617244193942 464650.4392947564 ... 48632057.084175125 48951609.26614704 49223067.557915695, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix         ...
# int64      float64            float64       ...      float64           float64            float64
# ----- ------------------ ------------------ ... ----------------- ------------------ -----------------
#     1 253.18993547632505 329.36320276036406 ... 51596910.87105521 51966753.603902794 52328844.62938529, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ... aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64            float64      ...     float64           float64            float64
# ----- ----------------- ------------------ ----------------- ... ---------------- ------------------ -----------------
#     1 261.8951051677421 326.89037966207866 453373.4744825377 ... 48998458.8447037 49346113.784454696 49672325.03860163, <QTable length=1>
#   id       xcenter            ycenter         aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                           ...
# int64      float64            float64            float64      ...      float64           float64           float64
# ----- ------------------ ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 254.78996666601685 329.35162373616913 546437.8996410077 ... 51611081.55473097 51974274.33146739 52338603.68608924, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0   ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64           float64       ...      float64           float64            float64
# ----- ----------------- ----------------- ------------------ ... ----------------- ------------------ -----------------
#     1 259.6650616971091 326.4587418116145 440412.70152751217 ... 48522261.73869232 48868544.346650995 49163749.01407922, <QTable length=1>
#   id       xcenter            ycenter         aperture_sum_0  ...  aperture_sum_438   aperture_sum_439 aperture_sum_440
#              pix                pix                           ...
# int64      float64            float64            float64      ...      float64            float64          float64
# ----- ------------------ ------------------ ----------------- ... ------------------ ----------------- ----------------
#     1 254.30495721164155 329.36585879780563 540676.3976989244 ... 51592011.154107824 51947781.85562295 52306760.6588198, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_438 aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64          float64           float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ---------------- -----------------
#     1 272.9053197918088 326.89419763624096 499474.5010549836 ... 49016097.42083713 49074111.9090441 49089023.43869646, <QTable length=1>
#   id      xcenter           ycenter         aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#             pix               pix                           ...
# int64     float64           float64            float64      ...      float64           float64           float64
# ----- ---------------- ------------------ ----------------- ... ----------------- ----------------- ------------------
#     1 259.855065400885 329.35767038697674 546084.0855247776 ... 51653942.49948772 52007511.36941844 52315300.485149615, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ... aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                           ...
# int64      float64           float64            float64      ...     float64           float64           float64
# ----- ----------------- ------------------ ----------------- ... ---------------- ----------------- -----------------
#     1 263.7401411333554 326.45529137687646 468265.4950446915 ... 48554914.3246404 48868913.42391957 49134951.73644412, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ------------------ ---------------- ... ----------------- ----------------- -----------------
#     1 255.10497280648744 329.36205658124646 515389.522628393 ... 51621318.11127339 51999186.49705659 52361801.93193433, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0   ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix               pix                            ...
# int64      float64           float64            float64       ...      float64           float64           float64
# ----- ----------------- ------------------ ------------------ ... ----------------- ----------------- -----------------
#     1 284.3905436753153 326.47580857832725 516880.20435269456 ... 47128181.36345074 47132239.60824377 47135804.76238751, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_438  aperture_sum_439   aperture_sum_440
#              pix                pix        ...
# int64      float64            float64      ...      float64           float64            float64
# ----- ------------------ ----------------- ... ----------------- ------------------ ------------------
#     1 256.56000116961343 329.3933026674474 ... 51622847.47155567 51995241.059728034 52360252.815945216, <QTable length=1>
#   id       xcenter            ycenter       aperture_sum_0  ...  aperture_sum_438 aperture_sum_439  aperture_sum_440
#              pix                pix                         ...
# int64      float64            float64          float64      ...      float64          float64           float64
# ----- ------------------ ----------------- ---------------- ... ----------------- ---------------- -----------------
#     1 263.88014386245345 326.4874724447626 463063.184683837 ... 48537758.35165214 48869386.4224725 49150552.30309308, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_438   aperture_sum_439  aperture_sum_440
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64            float64           float64
# ----- ------------------ ----------------- ----------------- ... ------------------ ----------------- -----------------
#     1 255.71998479502525 329.3705893439304 534004.2072784803 ... 51591766.460885346 51957788.57668986 52337361.65765061, <QTable length=1>
#   id       xcenter          ycenter        aperture_sum_0  ...  aperture_sum_438  aperture_sum_439  aperture_sum_440
#              pix              pix                          ...
# int64      float64          float64           float64      ...      float64           float64           float64
# ----- ----------------- ---------------- ----------------- ... ----------------- ----------------- -----------------
#     1 263.7001403536131 326.502095323309 456935.3329970185 ... 48532417.92956758 48848733.18015061 49123153.42568474]
# done 3
# done 4
# [INFO] Aperture Photometry per Image took 6469.630796432495 seconds for 41454 apertures.
# [INFO] Restructuring Aperture Photometry into DataFrames
#     aperture_sum_1x1  aperture_sum_6x1  aperture_sum_11x1  aperture_sum_16x1  \
# 0      549091.940846     549176.571742      549257.009671      549345.163686
# 1      482911.756793     482999.295940      483064.249169      483144.633776
# 2      535707.856011     535789.536016      535897.215036      535983.051801
# 3      462867.363509     462939.496711      463024.881210      463093.273251
# 4      555513.192416     555619.303081      555718.471965      555826.053339
# ..               ...               ...                ...                ...
# 89     516880.204353     516939.759415      517011.419917      517089.048038
# 90     564073.732131     564173.830548      564258.922869      564364.161825
# 91     463063.184684     463128.342812      463186.608660      463249.944544
# 92     534004.207278     534084.707495      534168.591760      534272.760130
# 93     456935.332997     457017.992464      457103.629671      457158.769141
#
#     aperture_sum_21x1  aperture_sum_26x1  aperture_sum_31x1  \
# 0       549455.396781      549546.500596      549627.031441
# 1       483213.151595      483293.102850      483359.765732
# 2       536104.318422      536195.561670      536268.091694
# 3       463157.602347      463236.326217      463304.695922
# 4       555907.173206      556008.589234      556090.842451
# ..                ...                ...                ...
# 89      517144.825422      517224.759321      517284.711181
# 90      564442.782391      564537.343840      564608.677711
# 91      463314.290605      463368.811824      463428.172348
# 92      534361.751973      534458.520786      534543.567722
# 93      457217.341330      457285.098897      457336.012547
#
#     aperture_sum_36x1  aperture_sum_41x1  aperture_sum_46x1  ...  \
# 0       549706.273308      549775.178935      549855.497188  ...
# 1       483430.828525      483488.634829      483561.692432  ...
# 2       536361.363898      536436.656303      536532.418022  ...
# 3       463370.723208      463425.312178      463498.540383  ...
# 4       556187.596082      556266.478162      556370.235159  ...
# ..                ...                ...                ...  ...
# 89      517332.531681      517353.947950      517416.729643  ...
# 90      564703.310966      564803.590446      564866.770266  ...
# 91      463499.908291      463538.659570      463603.505979  ...
# 92      534616.109948      534686.209249      534756.932536  ...
# 93      457391.170312      457441.040844      457498.257726  ...
#
#     aperture_sum_66x101  aperture_sum_71x101  aperture_sum_76x101  \
# 0          4.971875e+07         5.009439e+07         5.046749e+07
# 1          4.710223e+07         4.748516e+07         4.786748e+07
# 2          4.973582e+07         5.010661e+07         5.048230e+07
# 3          4.713478e+07         4.751387e+07         4.789227e+07
# 4          5.018836e+07         5.056315e+07         5.093360e+07
# ..                  ...                  ...                  ...
# 89         4.690485e+07         4.707096e+07         4.710612e+07
# 90         4.976224e+07         5.014151e+07         5.051694e+07
# 91         4.673340e+07         4.711064e+07         4.748749e+07
# 92         4.972695e+07         5.010975e+07         5.050245e+07
# 93         4.671545e+07         4.708900e+07         4.746553e+07
#
#     aperture_sum_81x101  aperture_sum_86x101  aperture_sum_91x101  \
# 0          5.083789e+07         5.120371e+07         5.157065e+07
# 1          4.824080e+07         4.860437e+07         4.895855e+07
# 2          5.086030e+07         5.122950e+07         5.159325e+07
# 3          4.826362e+07         4.862840e+07         4.898356e+07
# 4          5.130468e+07         5.167939e+07         5.205012e+07
# ..                  ...                  ...                  ...
# 89         4.711706e+07         4.712341e+07         4.712818e+07
# 90         5.088737e+07         5.125489e+07         5.162285e+07
# 91         4.784910e+07         4.819481e+07         4.853776e+07
# 92         5.087943e+07         5.123794e+07         5.159177e+07
# 93         4.783448e+07         4.819146e+07         4.853242e+07
#
#     aperture_sum_96x101  aperture_sum_101x101     xcenter     ycenter
# 0          5.193530e+07          5.229959e+07  253.304938  329.425051
# 1          4.930371e+07          4.962398e+07  263.870144  326.956437
# 2          5.195342e+07          5.231807e+07  253.464941  329.402053
# 3          4.932808e+07          4.964812e+07  262.960126  326.935457
# 4          5.241606e+07          5.277434e+07  255.139973  329.818032
# ..                  ...                   ...         ...         ...
# 89         4.713224e+07          4.713580e+07  284.390544  326.475809
# 90         5.199524e+07          5.236025e+07  256.560001  329.393303
# 91         4.886939e+07          4.915055e+07  263.880144  326.487472
# 92         5.195779e+07          5.233736e+07  255.719985  329.370589
# 93         4.884873e+07          4.912315e+07  263.700140  326.502095
#
# [94 rows x 443 columns]
# code took 111.24621161222458 minutes

# %%
planet_coarse_photometry_df = planet.photometry_df.copy()
planet.photometry_df
# Out:
#     aperture_sum_1x1  aperture_sum_6x1  aperture_sum_11x1  aperture_sum_16x1  \
# 0      549091.940846     549176.571742      549257.009671      549345.163686
# 1      482911.756793     482999.295940      483064.249169      483144.633776
# 2      535707.856011     535789.536016      535897.215036      535983.051801
# 3      462867.363509     462939.496711      463024.881210      463093.273251
# 4      555513.192416     555619.303081      555718.471965      555826.053339
# ..               ...               ...                ...                ...
# 89     516880.204353     516939.759415      517011.419917      517089.048038
# 90     564073.732131     564173.830548      564258.922869      564364.161825
# 91     463063.184684     463128.342812      463186.608660      463249.944544
# 92     534004.207278     534084.707495      534168.591760      534272.760130
# 93     456935.332997     457017.992464      457103.629671      457158.769141
#
#     aperture_sum_21x1  aperture_sum_26x1  aperture_sum_31x1  \
# 0       549455.396781      549546.500596      549627.031441
# 1       483213.151595      483293.102850      483359.765732
# 2       536104.318422      536195.561670      536268.091694
# 3       463157.602347      463236.326217      463304.695922
# 4       555907.173206      556008.589234      556090.842451
# ..                ...                ...                ...
# 89      517144.825422      517224.759321      517284.711181
# 90      564442.782391      564537.343840      564608.677711
# 91      463314.290605      463368.811824      463428.172348
# 92      534361.751973      534458.520786      534543.567722
# 93      457217.341330      457285.098897      457336.012547
#
#     aperture_sum_36x1  aperture_sum_41x1  aperture_sum_46x1  ...  \
# 0       549706.273308      549775.178935      549855.497188  ...
# 1       483430.828525      483488.634829      483561.692432  ...
# 2       536361.363898      536436.656303      536532.418022  ...
# 3       463370.723208      463425.312178      463498.540383  ...
# 4       556187.596082      556266.478162      556370.235159  ...
# ..                ...                ...                ...  ...
# 89      517332.531681      517353.947950      517416.729643  ...
# 90      564703.310966      564803.590446      564866.770266  ...
# 91      463499.908291      463538.659570      463603.505979  ...
# 92      534616.109948      534686.209249      534756.932536  ...
# 93      457391.170312      457441.040844      457498.257726  ...
#
#     aperture_sum_56x101  aperture_sum_61x101  aperture_sum_66x101  \
# 0          4.895683e+07         4.933985e+07         4.971875e+07
# 1          4.636133e+07         4.673057e+07         4.710223e+07
# 2          4.898371e+07         4.936217e+07         4.973582e+07
# 3          4.639279e+07         4.676188e+07         4.713478e+07
# 4          4.942569e+07         4.980890e+07         5.018836e+07
# ..                  ...                  ...                  ...
# 89         4.623615e+07         4.658558e+07         4.690485e+07
# 90         4.900663e+07         4.938112e+07         4.976224e+07
# 91         4.600655e+07         4.636844e+07         4.673340e+07
# 92         4.900097e+07         4.936069e+07         4.972695e+07
# 93         4.598568e+07         4.635004e+07         4.671545e+07
#
#     aperture_sum_71x101  aperture_sum_76x101  aperture_sum_81x101  \
# 0          5.009439e+07         5.046749e+07         5.083789e+07
# 1          4.748516e+07         4.786748e+07         4.824080e+07
# 2          5.010661e+07         5.048230e+07         5.086030e+07
# 3          4.751387e+07         4.789227e+07         4.826362e+07
# 4          5.056315e+07         5.093360e+07         5.130468e+07
# ..                  ...                  ...                  ...
# 89         4.707096e+07         4.710612e+07         4.711706e+07
# 90         5.014151e+07         5.051694e+07         5.088737e+07
# 91         4.711064e+07         4.748749e+07         4.784910e+07
# 92         5.010975e+07         5.050245e+07         5.087943e+07
# 93         4.708900e+07         4.746553e+07         4.783448e+07
#
#     aperture_sum_86x101  aperture_sum_91x101  aperture_sum_96x101  \
# 0          5.120371e+07         5.157065e+07         5.193530e+07
# 1          4.860437e+07         4.895855e+07         4.930371e+07
# 2          5.122950e+07         5.159325e+07         5.195342e+07
# 3          4.862840e+07         4.898356e+07         4.932808e+07
# 4          5.167939e+07         5.205012e+07         5.241606e+07
# ..                  ...                  ...                  ...
# 89         4.712341e+07         4.712818e+07         4.713224e+07
# 90         5.125489e+07         5.162285e+07         5.199524e+07
# 91         4.819481e+07         4.853776e+07         4.886939e+07
# 92         5.123794e+07         5.159177e+07         5.195779e+07
# 93         4.819146e+07         4.853242e+07         4.884873e+07
#
#     aperture_sum_101x101
# 0           5.229959e+07
# 1           4.962398e+07
# 2           5.231807e+07
# 3           4.964812e+07
# 4           5.277434e+07
# ..                   ...
# 89          4.713580e+07
# 90          5.236025e+07
# 91          4.915055e+07
# 92          5.233736e+07
# 93          4.912315e+07
#
# [94 rows x 441 columns]

# %%
coarse_snr_lightcurves = create_raw_lc_stddev(planet)
# create_raw_lc_stddev(planet)
#create_raw_lc_stddev(planet)
# print('1', coarse_snr_lightcurves)
coarse_min_snr = coarse_snr_lightcurves[coarse_snr_lightcurves.argmin()]
# print('2', coarse_min_snr)
coarse_min_snr_colname = planet.photometry_df.columns[coarse_snr_lightcurves.argmin()]
# print('3', coarse_min_snr_colname)
coarse_min_snr_col = planet.normed_photometry_df[coarse_min_snr_colname]
# print('4', coarse_min_snr_col)
coarse_temp = coarse_min_snr_colname.split('_')[-1].split('x')
coarse_min_snr_aper_width, coarse_min_snr_aper_height = np.int32(coarse_temp)
# print('5', coarse_temp)

# %%
info_message(f'Coarse Aperture Photometry Resulted in {coarse_min_snr:0.0f}ppm with '
             f'{coarse_min_snr_aper_width}x{coarse_min_snr_aper_height} aperture size')
# Out:
# [INFO] Coarse Aperture Photometry Resulted in 4122ppm with 71x101 aperture size

# %%
fine_buffer = 10
fine_aper_widths = np.arange(coarse_min_snr_aper_width - fine_buffer,
                             coarse_min_snr_aper_width + fine_buffer)

fine_aper_heights = np.arange(coarse_min_snr_aper_height - fine_buffer,
                              coarse_min_snr_aper_height + fine_buffer)

print(fine_aper_widths, fine_aper_heights)
print(coarse_min_snr_aper_width, coarse_min_snr_aper_height)
# Out:
# [61 62 63 64 65 66 67 68 69 70 71 72 73 74 75 76 77 78 79 80] [ 91  92  93  94  95  96  97  98  99 100 101 102 103 104 105 106 107 108
#  109 110]
# 71 101

# %%
planet.do_multi_phot(fine_aper_widths, fine_aper_heights)
# Out:
# [INFO] Beginning Multi-Aperture Photometry
# [253.30493772 263.87014367 253.46494084 262.96012593 255.13997349
#  261.35009454 254.89496871 260.24007291 255.15997388 259.81006452
#  255.07997232 266.58519659 254.9149691  259.51505877 255.01497105
#  262.29511297 253.85494844 260.54007875 252.99993177 263.09512856
#  253.82494785 261.93510595 254.9199692  262.43511569 252.68492563
#  263.77514182 255.01497105 263.10512875 253.1349344  264.02014659
#  252.78992768 260.26507339 255.21997505 260.15507125 253.41493986
#  263.25013158 252.96993119 262.37011443 253.50994171 260.35507515
#  253.56994288 260.36507534 252.46492134 260.47007739 255.25497573
#  259.36505585 252.82492836 260.30007408 252.43992086 259.49005829
#  254.90496891 262.20511121 255.69998441 260.30507417 252.04491316
#  260.96508704 258.0750307  260.16507144 256.57000136 263.10512875
#  252.91993021 260.82508431 253.09993372 263.70514045 256.66000312
#  263.0201271  252.86492914 262.77012222 254.95496988 259.77006374
#  253.26993704 260.450077   253.23993645 263.63513909 253.26993704
#  263.12012905 252.71492622 261.80510341 253.89994932 263.04012749
#  253.18993548 261.89510517 254.78996667 259.6650617  254.30495721
#  272.90531979 259.8550654  263.74014113 255.10497281 284.39054368
#  256.56000117 263.88014386 255.7199848  263.70014035] [329.42505107 326.95643732 329.40205332 326.93545651 329.81803164
#  326.51799449 329.38309742 326.48843507 329.38555618 326.48854345
#  329.35329202 326.47310095 329.77282521 326.88358987 329.34451187
#  326.46312348 329.76767326 326.46351759 329.35076914 326.46602903
#  329.41240324 326.48605655 329.34783864 326.46860621 329.36672039
#  326.47467248 329.3749786  327.32321383 329.40361434 326.46968718
#  329.45409976 326.96856938 329.44108344 326.96399074 329.77518042
#  326.55599708 329.42809411 326.53859055 329.4144255  326.92100531
#  329.80218414 326.46977977 329.39492828 327.32434452 329.38162772
#  326.8826313  329.3571063  326.47219055 329.35701777 326.86928774
#  329.35282618 326.46943513 329.3044049  326.48575994 329.37759316
#  326.48264938 329.37084509 326.48033196 329.39187955 326.49206871
#  329.38324361 326.91627947 329.43478679 326.54074203 329.47863473
#  326.53661616 329.40397134 326.93737917 329.81452707 326.5026013
#  329.37163561 326.52325612 329.35888983 326.92434298 330.20589453
#  326.47652832 329.3555384  326.48772664 329.35400906 326.46172442
#  329.36320276 326.89037966 329.35162374 326.45874181 329.3658588
#  326.89419764 329.35767039 326.45529138 329.36205658 326.47580858
#  329.39330267 326.48747244 329.37058934 326.50209532] [[253.30493772 329.42505107]
#  [263.87014367 326.95643732]
#  [253.46494084 329.40205332]
#  [262.96012593 326.93545651]
#  [255.13997349 329.81803164]
#  [261.35009454 326.51799449]
#  [254.89496871 329.38309742]
#  [260.24007291 326.48843507]
#  [255.15997388 329.38555618]
#  [259.81006452 326.48854345]
#  [255.07997232 329.35329202]
#  [266.58519659 326.47310095]
#  [254.9149691  329.77282521]
#  [259.51505877 326.88358987]
#  [255.01497105 329.34451187]
#  [262.29511297 326.46312348]
#  [253.85494844 329.76767326]
#  [260.54007875 326.46351759]
#  [252.99993177 329.35076914]
#  [263.09512856 326.46602903]
#  [253.82494785 329.41240324]
#  [261.93510595 326.48605655]
#  [254.9199692  329.34783864]
#  [262.43511569 326.46860621]
#  [252.68492563 329.36672039]
#  [263.77514182 326.47467248]
#  [255.01497105 329.3749786 ]
#  [263.10512875 327.32321383]
#  [253.1349344  329.40361434]
#  [264.02014659 326.46968718]
#  [252.78992768 329.45409976]
#  [260.26507339 326.96856938]
#  [255.21997505 329.44108344]
#  [260.15507125 326.96399074]
#  [253.41493986 329.77518042]
#  [263.25013158 326.55599708]
#  [252.96993119 329.42809411]
#  [262.37011443 326.53859055]
#  [253.50994171 329.4144255 ]
#  [260.35507515 326.92100531]
#  [253.56994288 329.80218414]
#  [260.36507534 326.46977977]
#  [252.46492134 329.39492828]
#  [260.47007739 327.32434452]
#  [255.25497573 329.38162772]
#  [259.36505585 326.8826313 ]
#  [252.82492836 329.3571063 ]
#  [260.30007408 326.47219055]
#  [252.43992086 329.35701777]
#  [259.49005829 326.86928774]
#  [254.90496891 329.35282618]
#  [262.20511121 326.46943513]
#  [255.69998441 329.3044049 ]
#  [260.30507417 326.48575994]
#  [252.04491316 329.37759316]
#  [260.96508704 326.48264938]
#  [258.0750307  329.37084509]
#  [260.16507144 326.48033196]
#  [256.57000136 329.39187955]
#  [263.10512875 326.49206871]
#  [252.91993021 329.38324361]
#  [260.82508431 326.91627947]
#  [253.09993372 329.43478679]
#  [263.70514045 326.54074203]
#  [256.66000312 329.47863473]
#  [263.0201271  326.53661616]
#  [252.86492914 329.40397134]
#  [262.77012222 326.93737917]
#  [254.95496988 329.81452707]
#  [259.77006374 326.5026013 ]
#  [253.26993704 329.37163561]
#  [260.450077   326.52325612]
#  [253.23993645 329.35888983]
#  [263.63513909 326.92434298]
#  [253.26993704 330.20589453]
#  [263.12012905 326.47652832]
#  [252.71492622 329.3555384 ]
#  [261.80510341 326.48772664]
#  [253.89994932 329.35400906]
#  [263.04012749 326.46172442]
#  [253.18993548 329.36320276]
#  [261.89510517 326.89037966]
#  [254.78996667 329.35162374]
#  [259.6650617  326.45874181]
#  [254.30495721 329.3658588 ]
#  [272.90531979 326.89419764]
#  [259.8550654  329.35767039]
#  [263.74014113 326.45529138]
#  [255.10497281 329.36205658]
#  [284.39054368 326.47580858]
#  [256.56000117 329.39330267]
#  [263.88014386 326.48747244]
#  [255.7199848  329.37058934]
#  [263.70014035 326.50209532]]
# [INFO] Creating Apertures
# 100%|███████████████████████████████████████████████████████████████████████████████████| 94/94 [00:01<00:00, 81.23it/s]
# [INFO] Configuing Photoutils.Aperture_Photometry
# [INFO] Computing Aperture Photometry per Image
# done 1
# <multiprocessing.pool.Pool state=RUN pool_size=7>
# done 2
# [<QTable length=1>
#   id       xcenter           ycenter       aperture_sum_0 ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                        ...
# int64      float64           float64          float64     ...      float64           float64           float64
# ----- ------------------ ---------------- --------------- ... ----------------- ----------------- ------------------
#     1 253.30493771808415 329.425051070842 46683250.375983 ... 51580060.09875366 51654563.93526215 51729157.774577335, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64           float64
# ----- ----------------- ----------------- ----------------- ... ----------------- ----------------- ------------------
#     1 263.8701436675179 326.9564373235543 44326333.71578531 ... 50217096.01532845 50293247.05280096 50369248.628929965, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0   ... aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                           ...
# int64      float64            float64           float64       ...     float64           float64           float64
# ----- ------------------ ----------------- ------------------ ... ---------------- ----------------- -----------------
#     1 253.46494083705335 329.4020533155685 46669546.484608896 ... 51605473.8444705 51681922.30107515 51758174.92777738, <QTable length=1>
#   id       xcenter            ycenter         aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                           ...
# int64      float64            float64            float64      ...      float64           float64           float64
# ----- ------------------ ------------------ ----------------- ... ------------------ ---------------- -----------------
#     1 262.96012592838065 326.93545651468276 44340283.69143746 ... 50238901.526846096 50314847.8612722 50390873.87030414, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64            float64           float64
# ----- ------------------ ----------------- ----------------- ... ------------------ ----------------- -----------------
#     1 255.13997348876194 329.8180316400627 47128121.30913563 ... 51842694.458149694 51917432.82940358 51992420.26333607, <QTable length=1>
#   id       xcenter           ycenter       aperture_sum_0  ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix               pix                         ...
# int64      float64           float64          float64      ...      float64            float64           float64
# ----- ----------------- ----------------- ---------------- ... ------------------ ----------------- -----------------
#     1 261.3500945437533 326.5179944856611 43934638.5000127 ... 49815008.649269715 49890312.15782999 49964887.59491478, <QTable length=1>
#   id       xcenter          ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix              pix                          ...
# int64      float64          float64           float64      ...      float64           float64           float64
# ----- ----------------- ---------------- ----------------- ... ----------------- ----------------- -----------------
#     1 254.8949687128404 329.383097421958 46689205.93081354 ... 51796019.29641088 51871612.68661807 51947189.11543532, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64           float64
# ----- ----------------- ------------------ ---------------- ... ----------------- ----------------- ------------------
#     1 260.2400729059046 326.48843506912397 43963566.9624882 ... 49806070.11504887 49882586.58974935 49958536.431938104, <QTable length=1>
#   id       xcenter           ycenter       aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                         ...
# int64      float64           float64          float64      ...      float64           float64           float64
# ----- ----------------- ----------------- ---------------- ... ----------------- ----------------- -----------------
#     1 255.1599738786331 329.3855561764192 46681449.3815064 ... 51816486.91625181 51891159.73598922 51965845.82053705, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64           float64
# ----- ----------------- ----------------- ----------------- ... ----------------- ----------------- -----------------
#     1 259.8100645236749 326.4885434541649 43954859.04888613 ... 49806313.49991165 49881459.63528742 49956983.33384607, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0   ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64           float64       ...      float64           float64            float64
# ----- ----------------- ----------------- ------------------ ... ----------------- ------------------ -----------------
#     1 255.0799723191485 329.3532920229721 46693461.666336626 ... 51803555.99620572 51877926.141171716 51952429.32241513, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64            float64           float64
# ----- ------------------ ----------------- ----------------- ... ------------------ ----------------- -----------------
#     1 266.58519659252613 326.4731009494542 43972800.50243594 ... 49837852.629575774 49915512.86875209 49993235.39609916, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_397   aperture_sum_398   aperture_sum_399
#              pix                pix        ...
# int64      float64            float64      ...      float64            float64            float64
# ----- ------------------ ----------------- ... ------------------ ------------------ -----------------
#     1 254.91496910271155 329.7728252105946 ... 51837777.259152964 51912817.194590494 51988102.53974804, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64           float64            float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ------------------ -----------------
#     1 259.5150587730755 326.88358987276143 44308664.41184643 ... 50176031.41623181 50251038.783527985 50326312.48780063, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix                pix        ...
# int64      float64            float64      ...      float64           float64            float64
# ----- ------------------ ----------------- ... ----------------- ------------------ ------------------
#     1 255.01497105206727 329.3445118713696 ... 51791785.98901457 51867487.151468724 51942962.816979274, <QTable length=1>
#   id      xcenter           ycenter         aperture_sum_0  ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#             pix               pix                           ...
# int64     float64           float64            float64      ...      float64           float64            float64
# ----- ---------------- ------------------ ----------------- ... ----------------- ------------------ -----------------
#     1 262.295112965165 326.46312348310795 43956035.54799711 ... 49809736.96111063 49886739.073677815 49963322.90611295, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- -----------------
#     1 253.85494843954072 329.7676732615574 47129171.14288594 ... 51669442.36241531 51744841.59618788 51820593.10972882, <QTable length=1>
#   id       xcenter           ycenter       ...  aperture_sum_397   aperture_sum_398   aperture_sum_399
#              pix               pix         ...
# int64      float64           float64       ...      float64            float64            float64
# ----- ----------------- ------------------ ... ------------------ ------------------ ------------------
#     1 260.5400787539718 326.46351759248057 ... 49776569.739307396 49852894.525130995 49929632.793808885, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- -----------------
#     1 252.99993177254916 329.3507691407899 46653763.53029574 ... 51514379.95228725 51589699.84911408 51664995.38131092, <QTable length=1>
#   id       xcenter           ycenter       aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                         ...
# int64      float64           float64          float64      ...      float64           float64           float64
# ----- ----------------- ----------------- ---------------- ... ----------------- ----------------- -----------------
#     1 263.0951285600109 326.4660290319205 43945047.2713615 ... 49799332.72922499 49876047.76497195 49952908.03579147, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0   ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                           ...
# int64      float64            float64           float64       ...      float64           float64           float64
# ----- ------------------ ----------------- ------------------ ... ----------------- ----------------- -----------------
#     1 253.82494785473398 329.4124032396685 46668177.546321556 ... 51621230.14967131 51697855.42481659 51774298.56995427, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64            float64
# ----- ----------------- ----------------- ----------------- ... ----------------- ------------------ -----------------
#     1 261.9351059474844 326.4860565472312 43928690.19446775 ... 49798315.12782334 49874134.469368614 49950362.12255096, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64            float64           float64
# ----- ------------------ ---------------- ----------------- ... ------------------ ----------------- -----------------
#     1 254.91996920017934 329.347838643757 46654809.92364609 ... 51766575.894242175 51843143.97853483 51919682.28772026, <QTable length=1>
#   id      xcenter           ycenter        aperture_sum_0  ... aperture_sum_397  aperture_sum_398  aperture_sum_399
#             pix               pix                          ...
# int64     float64           float64           float64      ...     float64           float64           float64
# ----- ---------------- ----------------- ----------------- ... ---------------- ----------------- -----------------
#     1 262.435115694263 326.4686062084583 43910358.67122638 ... 49770169.2545831 49845621.53588948 49921265.04084396, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0   ...  aperture_sum_397 aperture_sum_398  aperture_sum_399
#              pix                pix                           ...
# int64      float64            float64           float64       ...      float64          float64           float64
# ----- ------------------ ----------------- ------------------ ... ----------------- ---------------- -----------------
#     1 252.68492563207857 329.3667203869603 46643779.640481025 ... 51459314.16916862 51534721.5507147 51609656.21169425, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64           float64
# ----- ----------------- ----------------- ----------------- ... ----------------- ----------------- -----------------
#     1 263.7751418156299 326.4746724844748 43923507.90514573 ... 49769282.08825624 49844985.60155118 49921451.82458623, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ... aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...     float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ---------------- ----------------- -----------------
#     1 255.01497105206727 329.3749786038794 46654993.61976162 ... 51761017.5195599 51836902.55918306 51912579.92270935, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64            float64           float64
# ----- ------------------ ----------------- ----------------- ... ------------------ ----------------- -----------------
#     1 263.10512875494646 327.3232138290779 44706493.23012403 ... 50652448.947279334 50728342.83159098 50804556.33467023, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0   ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64           float64       ...      float64           float64           float64
# ----- ----------------- ----------------- ------------------ ... ----------------- ----------------- ------------------
#     1 253.1349344041794 329.4036143402776 46649433.883569136 ... 51515547.60052381 51591079.93808685 51666722.547955096, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- ------------------
#     1 264.02014659155145 326.4696871818514 43940333.03616401 ... 49764204.60323078 49839800.43122799 49914838.393526085, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64           float64           float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 252.7899276789021 329.45409975752455 46677577.14150602 ... 51494066.69583797 51568811.80700817 51643614.55109969, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix                pix         ...
# int64      float64            float64       ...      float64            float64           float64
# ----- ------------------ ------------------ ... ------------------ ------------------ ----------------
#     1 260.26507339324354 326.96856938289204 ... 50190939.104085535 50268584.450646445 50346207.4318204, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix                pix         ...
# int64      float64            float64       ...      float64            float64           float64
# ----- ------------------ ------------------ ... ------------------ ----------------- ------------------
#     1 255.21997504824657 329.44108344078046 ... 51845600.925414026 51919096.70180675 51992286.051049225, <QTable length=1>
#   id       xcenter           ycenter       aperture_sum_0 ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                        ...
# int64      float64           float64          float64     ...      float64           float64           float64
# ----- ----------------- ----------------- --------------- ... ----------------- ----------------- -----------------
#     1 260.1550712489522 326.9639907423599 44326441.592425 ... 50183793.34100978 50261811.70696783 50339509.98905709, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix                pix         ...
# int64      float64            float64       ...      float64           float64            float64
# ----- ------------------ ------------------ ... ----------------- ------------------ -----------------
#     1 253.41493986237546 329.77518041644504 ... 51607915.25089362 51683198.372345015 51759036.62782938, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64            float64           float64
# ----- ----------------- ----------------- ----------------- ... ------------------ ----------------- ------------------
#     1 263.2501315815123 326.5559970816038 43980862.79632464 ... 49817273.187769406 49893875.45037727 49969605.192414716, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix                pix         ...
# int64      float64            float64       ...      float64           float64            float64
# ----- ------------------ ------------------ ... ----------------- ------------------ -----------------
#     1 252.96993118774245 329.42809411228507 ... 51550103.52125749 51626312.276186846 51702395.78869322, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0   ... aperture_sum_397 aperture_sum_398  aperture_sum_399
#              pix               pix                            ...
# int64      float64           float64            float64       ...     float64          float64           float64
# ----- ----------------- ------------------ ------------------ ... ---------------- ---------------- -----------------
#     1 262.3701144271818 326.53859054825824 43962586.231439725 ... 49794338.2516767 49870533.6782617 49946966.88592543, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398 aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64          float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ----------------- ----------------
#     1 253.50994171426345 329.4144254976702 46690085.10881446 ... 51612755.63696995 51688483.75750706  51764305.254073, <QTable length=1>
#   id       xcenter          ycenter        aperture_sum_0   ... aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix              pix                           ...
# int64      float64          float64           float64       ...     float64           float64           float64
# ----- ----------------- ---------------- ------------------ ... ---------------- ----------------- -----------------
#     1 260.3550751476637 326.921005309694 44316141.547740705 ... 50198104.7353262 50273451.68462096 50348833.00536942, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ... aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...     float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ---------------- ----------------- -----------------
#     1 253.56994288387688 329.8021841440286 47152408.83577438 ... 51662455.7206188 51738070.12505793 51813428.77012823, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0   ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                           ...
# int64      float64            float64           float64       ...      float64           float64           float64
# ----- ------------------ ----------------- ------------------ ... ----------------- ----------------- -----------------
#     1 260.36507534259925 326.4697797746798 43956639.216170415 ... 49811420.57697057 49888101.66121651 49964744.58828209, <QTable length=1>
#   id       xcenter           ycenter       aperture_sum_0   ...  aperture_sum_397 aperture_sum_398  aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64          float64       ...      float64          float64           float64
# ----- ------------------ --------------- ------------------ ... ----------------- ---------------- ------------------
#     1 252.46492134349597 329.39492827758 46669775.345625825 ... 51478190.96403508 51553207.1127326 51628206.191606656, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64           float64           float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 260.4700773894228 327.32434451900883 44817509.92761493 ... 50752106.74871627 50828072.34446579 50903703.46620106, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0   ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                           ...
# int64      float64            float64           float64       ...      float64           float64           float64
# ----- ------------------ ----------------- ------------------ ... ----------------- ----------------- -----------------
#     1 255.25497573052104 329.3816277211552 46669066.472844765 ... 51824049.93891671 51898364.59380949 51972494.47971162, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64           float64            float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ------------------ -----------------
#     1 259.3650558490419 326.88263129646776 44369058.39847283 ... 50272221.59002628 50347748.274734244 50422807.19729776, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0   ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                            ...
# int64      float64           float64            float64       ...      float64           float64           float64
# ----- ----------------- ------------------ ------------------ ... ----------------- ----------------- -----------------
#     1 252.8249283611766 329.35710630257853 46687300.960200556 ... 51491894.68270264 51569275.18084114 51646505.35346975, <QTable length=1>
#   id      xcenter           ycenter        aperture_sum_0  ...  aperture_sum_397   aperture_sum_398   aperture_sum_399
#             pix               pix                          ...
# int64     float64           float64           float64      ...      float64            float64            float64
# ----- ---------------- ----------------- ----------------- ... ------------------ ------------------ -----------------
#     1 260.300074075518 326.4721905533514 43928406.24264308 ... 49788892.046272725 49864248.109797716 49939310.04984741, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64            float64
# ----- ------------------ ---------------- ----------------- ... ----------------- ------------------ ------------------
#     1 252.43992085615704 329.357017767925 46678720.27157869 ... 51470377.03547422 51543958.331195526 51617610.798553534, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ... aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...     float64           float64           float64
# ----- ------------------ ----------------- ----------------- ... ---------------- ----------------- -----------------
#     1 259.49005828573655 326.8692877360934 44298939.42027097 ... 50170021.5290277 50245109.28619833 50320277.89391418, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_397   aperture_sum_398   aperture_sum_399
#              pix                pix        ...
# int64      float64            float64      ...      float64            float64            float64
# ----- ------------------ ----------------- ... ------------------ ------------------ ------------------
#     1 254.90496890777598 329.3528261773121 ... 51761005.829020195 51837631.098477356 51914318.860047296, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix                pix         ...
# int64      float64            float64       ...      float64            float64           float64
# ----- ------------------ ------------------ ... ------------------ ----------------- -----------------
#     1 262.20511121074486 326.46943513122096 ... 49818114.126721874 49893948.16335227 49969500.95311512, <QTable length=1>
#   id       xcenter            ycenter       aperture_sum_0  ... aperture_sum_397 aperture_sum_398  aperture_sum_399
#              pix                pix                         ...
# int64      float64            float64          float64      ...     float64          float64           float64
# ----- ------------------ ----------------- ---------------- ... ---------------- ---------------- ------------------
#     1 255.69998440515408 329.3044049006583 46693199.7992115 ... 51863723.2418744 51939420.1242601 52015280.015314296, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ... aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64           float64      ...     float64           float64            float64
# ----- ----------------- ----------------- ----------------- ... ---------------- ------------------ -----------------
#     1 260.3050741729858 326.4857599387607 43936872.50725544 ... 49791623.0418155 49867752.863053724 49944154.25937717, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix                pix        ...
# int64      float64            float64      ...      float64           float64            float64
# ----- ------------------ ----------------- ... ----------------- ------------------ ------------------
#     1 252.04491315620186 329.3775931597561 ... 51400004.90967837 51474921.045921125 51549598.293748915, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64            float64           float64
# ----- ----------------- ------------------ ----------------- ... ------------------ ----------------- -----------------
#     1 260.9650870387337 326.48264937897085 43917712.86779743 ... 49823657.775563866 49898847.86008779 49974170.04997857, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64           float64           float64
# ----- ----------------- ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 258.0750307023529 329.37084508523793 46710708.58537363 ... 52145587.49128709 52222443.13890964 52299157.47732198, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix                pix                          ...
# int64      float64            float64           float64      ...      float64           float64            float64
# ----- ------------------ ----------------- ----------------- ... ----------------- ------------------ -----------------
#     1 260.16507144388777 326.4803319632834 43887904.59772737 ... 49817313.86263955 49891416.164239414 49964844.55655154, <QTable length=1>
#   id      xcenter           ycenter         aperture_sum_0  ...  aperture_sum_397 aperture_sum_398  aperture_sum_399
#             pix               pix                           ...
# int64     float64           float64            float64      ...      float64          float64           float64
# ----- ---------------- ------------------ ----------------- ... ----------------- ---------------- -----------------
#     1 256.570001364549 329.39187954631944 46699474.23318856 ... 51962014.23128479 52038922.5881045 52115150.30866395, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_397   aperture_sum_398   aperture_sum_399
#              pix                pix         ...
# int64      float64            float64       ...      float64            float64            float64
# ----- ------------------ ------------------ ... ------------------ ------------------ -----------------
#     1 263.10512875494646 326.49206870713454 ... 49762526.973039515 49838960.293700054 49916465.88546543, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix               pix                          ...
# int64      float64           float64           float64      ...      float64           float64            float64
# ----- ----------------- ------------------ ---------------- ... ----------------- ------------------ ------------------
#     1 252.9199302130646 329.38324361070255 46654389.5728562 ... 51454084.95325313 51529318.940718554 51604368.176659815, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix                pix         ...
# int64      float64            float64       ...      float64           float64            float64
# ----- ------------------ ------------------ ... ----------------- ------------------ -----------------
#     1 260.82508430963566 326.91627947020055 ... 50255353.13175052 50332235.753498904 50409403.77727708, <QTable length=1>
#   id       xcenter          ycenter        aperture_sum_0  ...  aperture_sum_397  aperture_sum_398 aperture_sum_399
#              pix              pix                          ...
# int64      float64          float64           float64      ...      float64           float64          float64
# ----- ----------------- ---------------- ----------------- ... ----------------- ----------------- ----------------
#     1 253.0999337219049 329.434786789518 46665500.36739996 ... 51541694.97838726 51616158.09055718 51690775.7537078, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64            float64           float64
# ----- ----------------- ------------------ ----------------- ... ------------------ ----------------- -----------------
#     1 263.7051404510809 326.54074202548225 43985893.99887111 ... 49827229.715667844 49901774.57958409 49976856.24408184, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix         ...
# int64      float64            float64       ...      float64           float64           float64
# ----- ------------------ ------------------ ... ----------------- ----------------- -----------------
#     1 256.66000311896914 329.47863473224317 ... 51999441.87912833 52074787.55371344 52151554.33601222, <QTable length=1>
#   id       xcenter           ycenter        aperture_sum_0   ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64           float64       ...      float64           float64           float64
# ----- ----------------- ----------------- ------------------ ... ------------------ ---------------- -----------------
#     1 263.0201270979941 326.5366161584504 43954865.803187795 ... 49797620.822417825 49873351.7514961 49948281.62366733, <QTable length=1>
#   id       xcenter            ycenter      ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix                pix        ...
# int64      float64            float64      ...      float64            float64           float64
# ----- ------------------ ----------------- ... ------------------ ----------------- ------------------
#     1 252.86492914091892 329.4039713357102 ... 51500356.648029804 51576018.95010902 51651493.919622414, <QTable length=1>
#   id       xcenter            ycenter        aperture_sum_0   ...  aperture_sum_397  aperture_sum_398 aperture_sum_399
#              pix                pix                           ...
# int64      float64            float64           float64       ...      float64           float64          float64
# ----- ------------------ ----------------- ------------------ ... ----------------- ----------------- ----------------
#     1 262.77012222460473 326.9373791746968 44335594.496251635 ... 50211270.81545331 50286835.11957719 50363115.4486671, <QTable length=1>
#   id       xcenter            ycenter       ...  aperture_sum_397  aperture_sum_398   aperture_sum_399
#              pix                pix         ...
# int64      float64            float64       ...      float64           float64            float64
# ----- ------------------ ------------------ ... ----------------- ------------------ -----------------
#     1 254.95496988245384 329.81452706617483 ... 51840374.28933339 51916013.588816516 51990901.51712338, <QTable length=1>
#   id       xcenter           ycenter         aperture_sum_0  ...  aperture_sum_397   aperture_sum_398  aperture_sum_399
#              pix               pix                           ...
# int64      float64           float64            float64      ...      float64            float64           float64
# ----- ----------------- ------------------ ----------------- ... ------------------ ----------------- -----------------
#     1 259.7700637439326 326.50260130039993 43965105.93480983 ... 49793738.761208795 49868986.91491888 49944987.35390574, <QTable length=1>
#   id       xcenter            ycenter         aperture_sum_0  ...  aperture_sum_397  aperture_sum_398  aperture_sum_399
#              pix                pix                           ...
# int64      float64            float64            float64      ...      float64           float64           float64
# ----- ------------------ ------------------ ----------------- ... ----------------- ----------------- -----------------
#     1 253.26993703580968 329.37163560618467 46630557.04820005 ... 51542050.80806357 51618749.01766521 51695058.50941425, <QTable length=1>
# ...
# [INFO] Adding column aperture_sum_63x98 to self.photometry_df
# [INFO] Adding column aperture_sum_64x98 to self.photometry_df
# [INFO] Adding column aperture_sum_65x98 to self.photometry_df
# [INFO] Adding column aperture_sum_66x98 to self.photometry_df
# [INFO] Adding column aperture_sum_67x98 to self.photometry_df
# [INFO] Adding column aperture_sum_68x98 to self.photometry_df
# [INFO] Adding column aperture_sum_69x98 to self.photometry_df
# [INFO] Adding column aperture_sum_70x98 to self.photometry_df
# [INFO] Adding column aperture_sum_71x98 to self.photometry_df
# [INFO] Adding column aperture_sum_72x98 to self.photometry_df
# [INFO] Adding column aperture_sum_73x98 to self.photometry_df
# [INFO] Adding column aperture_sum_74x98 to self.photometry_df
# [INFO] Adding column aperture_sum_75x98 to self.photometry_df
# [INFO] Adding column aperture_sum_76x98 to self.photometry_df
# [INFO] Adding column aperture_sum_77x98 to self.photometry_df
# [INFO] Adding column aperture_sum_78x98 to self.photometry_df
# [INFO] Adding column aperture_sum_79x98 to self.photometry_df
# [INFO] Adding column aperture_sum_80x98 to self.photometry_df
# [INFO] Adding column aperture_sum_61x99 to self.photometry_df
# [INFO] Adding column aperture_sum_62x99 to self.photometry_df
# [INFO] Adding column aperture_sum_63x99 to self.photometry_df
# [INFO] Adding column aperture_sum_64x99 to self.photometry_df
# [INFO] Adding column aperture_sum_65x99 to self.photometry_df
# [INFO] Adding column aperture_sum_66x99 to self.photometry_df
# [INFO] Adding column aperture_sum_67x99 to self.photometry_df
# [INFO] Adding column aperture_sum_68x99 to self.photometry_df
# [INFO] Adding column aperture_sum_69x99 to self.photometry_df
# [INFO] Adding column aperture_sum_70x99 to self.photometry_df
# [INFO] Adding column aperture_sum_71x99 to self.photometry_df
# [INFO] Adding column aperture_sum_72x99 to self.photometry_df
# [INFO] Adding column aperture_sum_73x99 to self.photometry_df
# [INFO] Adding column aperture_sum_74x99 to self.photometry_df
# [INFO] Adding column aperture_sum_75x99 to self.photometry_df
# [INFO] Adding column aperture_sum_76x99 to self.photometry_df
# [INFO] Adding column aperture_sum_77x99 to self.photometry_df
# [INFO] Adding column aperture_sum_78x99 to self.photometry_df
# [INFO] Adding column aperture_sum_79x99 to self.photometry_df
# [INFO] Adding column aperture_sum_80x99 to self.photometry_df
# [INFO] Adding column aperture_sum_61x100 to self.photometry_df
# [INFO] Adding column aperture_sum_62x100 to self.photometry_df
# [INFO] Adding column aperture_sum_63x100 to self.photometry_df
# [INFO] Adding column aperture_sum_64x100 to self.photometry_df
# [INFO] Adding column aperture_sum_65x100 to self.photometry_df
# [INFO] Adding column aperture_sum_66x100 to self.photometry_df
# [INFO] Adding column aperture_sum_67x100 to self.photometry_df
# [INFO] Adding column aperture_sum_68x100 to self.photometry_df
# [INFO] Adding column aperture_sum_69x100 to self.photometry_df
# [INFO] Adding column aperture_sum_70x100 to self.photometry_df
# [INFO] Adding column aperture_sum_71x100 to self.photometry_df
# [INFO] Adding column aperture_sum_72x100 to self.photometry_df
# [INFO] Adding column aperture_sum_73x100 to self.photometry_df
# [INFO] Adding column aperture_sum_74x100 to self.photometry_df
# [INFO] Adding column aperture_sum_75x100 to self.photometry_df
# [INFO] Adding column aperture_sum_76x100 to self.photometry_df
# [INFO] Adding column aperture_sum_77x100 to self.photometry_df
# [INFO] Adding column aperture_sum_78x100 to self.photometry_df
# [INFO] Adding column aperture_sum_79x100 to self.photometry_df
# [INFO] Adding column aperture_sum_80x100 to self.photometry_df
# [INFO] Adding column aperture_sum_62x101 to self.photometry_df
# [INFO] Adding column aperture_sum_63x101 to self.photometry_df
# [INFO] Adding column aperture_sum_64x101 to self.photometry_df
# [INFO] Adding column aperture_sum_65x101 to self.photometry_df
# [INFO] Adding column aperture_sum_67x101 to self.photometry_df
# [INFO] Adding column aperture_sum_68x101 to self.photometry_df
# [INFO] Adding column aperture_sum_69x101 to self.photometry_df
# [INFO] Adding column aperture_sum_70x101 to self.photometry_df
# [INFO] Adding column aperture_sum_72x101 to self.photometry_df
# [INFO] Adding column aperture_sum_73x101 to self.photometry_df
# [INFO] Adding column aperture_sum_74x101 to self.photometry_df
# [INFO] Adding column aperture_sum_75x101 to self.photometry_df
# [INFO] Adding column aperture_sum_77x101 to self.photometry_df
# [INFO] Adding column aperture_sum_78x101 to self.photometry_df
# [INFO] Adding column aperture_sum_79x101 to self.photometry_df
# [INFO] Adding column aperture_sum_80x101 to self.photometry_df
# [INFO] Adding column aperture_sum_61x102 to self.photometry_df
# [INFO] Adding column aperture_sum_62x102 to self.photometry_df
# [INFO] Adding column aperture_sum_63x102 to self.photometry_df
# [INFO] Adding column aperture_sum_64x102 to self.photometry_df
# [INFO] Adding column aperture_sum_65x102 to self.photometry_df
# [INFO] Adding column aperture_sum_66x102 to self.photometry_df
# [INFO] Adding column aperture_sum_67x102 to self.photometry_df
# [INFO] Adding column aperture_sum_68x102 to self.photometry_df
# [INFO] Adding column aperture_sum_69x102 to self.photometry_df
# [INFO] Adding column aperture_sum_70x102 to self.photometry_df
# [INFO] Adding column aperture_sum_71x102 to self.photometry_df
# [INFO] Adding column aperture_sum_72x102 to self.photometry_df
# [INFO] Adding column aperture_sum_73x102 to self.photometry_df
# [INFO] Adding column aperture_sum_74x102 to self.photometry_df
# [INFO] Adding column aperture_sum_75x102 to self.photometry_df
# [INFO] Adding column aperture_sum_76x102 to self.photometry_df
# [INFO] Adding column aperture_sum_77x102 to self.photometry_df
# [INFO] Adding column aperture_sum_78x102 to self.photometry_df
# [INFO] Adding column aperture_sum_79x102 to self.photometry_df
# [INFO] Adding column aperture_sum_80x102 to self.photometry_df
# [INFO] Adding column aperture_sum_61x103 to self.photometry_df
# [INFO] Adding column aperture_sum_62x103 to self.photometry_df
# [INFO] Adding column aperture_sum_63x103 to self.photometry_df
# [INFO] Adding column aperture_sum_64x103 to self.photometry_df
# [INFO] Adding column aperture_sum_65x103 to self.photometry_df
# [INFO] Adding column aperture_sum_66x103 to self.photometry_df
# [INFO] Adding column aperture_sum_67x103 to self.photometry_df
# [INFO] Adding column aperture_sum_68x103 to self.photometry_df
# [INFO] Adding column aperture_sum_69x103 to self.photometry_df
# [INFO] Adding column aperture_sum_70x103 to self.photometry_df
# [INFO] Adding column aperture_sum_71x103 to self.photometry_df
# [INFO] Adding column aperture_sum_72x103 to self.photometry_df
# [INFO] Adding column aperture_sum_73x103 to self.photometry_df
# [INFO] Adding column aperture_sum_74x103 to self.photometry_df
# [INFO] Adding column aperture_sum_75x103 to self.photometry_df
# [INFO] Adding column aperture_sum_76x103 to self.photometry_df
# [INFO] Adding column aperture_sum_77x103 to self.photometry_df
# [INFO] Adding column aperture_sum_78x103 to self.photometry_df
# [INFO] Adding column aperture_sum_79x103 to self.photometry_df
# [INFO] Adding column aperture_sum_80x103 to self.photometry_df
# [INFO] Adding column aperture_sum_61x104 to self.photometry_df
# [INFO] Adding column aperture_sum_62x104 to self.photometry_df
# [INFO] Adding column aperture_sum_63x104 to self.photometry_df
# [INFO] Adding column aperture_sum_64x104 to self.photometry_df
# [INFO] Adding column aperture_sum_65x104 to self.photometry_df
# [INFO] Adding column aperture_sum_66x104 to self.photometry_df
# [INFO] Adding column aperture_sum_67x104 to self.photometry_df
# [INFO] Adding column aperture_sum_68x104 to self.photometry_df
# [INFO] Adding column aperture_sum_69x104 to self.photometry_df
# [INFO] Adding column aperture_sum_70x104 to self.photometry_df
# [INFO] Adding column aperture_sum_71x104 to self.photometry_df
# [INFO] Adding column aperture_sum_72x104 to self.photometry_df
# [INFO] Adding column aperture_sum_73x104 to self.photometry_df
# [INFO] Adding column aperture_sum_74x104 to self.photometry_df
# [INFO] Adding column aperture_sum_75x104 to self.photometry_df
# [INFO] Adding column aperture_sum_76x104 to self.photometry_df
# [INFO] Adding column aperture_sum_77x104 to self.photometry_df
# [INFO] Adding column aperture_sum_78x104 to self.photometry_df
# [INFO] Adding column aperture_sum_79x104 to self.photometry_df
# [INFO] Adding column aperture_sum_80x104 to self.photometry_df
# [INFO] Adding column aperture_sum_61x105 to self.photometry_df
# [INFO] Adding column aperture_sum_62x105 to self.photometry_df
# [INFO] Adding column aperture_sum_63x105 to self.photometry_df
# [INFO] Adding column aperture_sum_64x105 to self.photometry_df
# [INFO] Adding column aperture_sum_65x105 to self.photometry_df
# [INFO] Adding column aperture_sum_66x105 to self.photometry_df
# [INFO] Adding column aperture_sum_67x105 to self.photometry_df
# [INFO] Adding column aperture_sum_68x105 to self.photometry_df
# [INFO] Adding column aperture_sum_69x105 to self.photometry_df
# [INFO] Adding column aperture_sum_70x105 to self.photometry_df
# [INFO] Adding column aperture_sum_71x105 to self.photometry_df
# [INFO] Adding column aperture_sum_72x105 to self.photometry_df
# [INFO] Adding column aperture_sum_73x105 to self.photometry_df
# [INFO] Adding column aperture_sum_74x105 to self.photometry_df
# [INFO] Adding column aperture_sum_75x105 to self.photometry_df
# [INFO] Adding column aperture_sum_76x105 to self.photometry_df
# [INFO] Adding column aperture_sum_77x105 to self.photometry_df
# [INFO] Adding column aperture_sum_78x105 to self.photometry_df
# [INFO] Adding column aperture_sum_79x105 to self.photometry_df
# [INFO] Adding column aperture_sum_80x105 to self.photometry_df
# [INFO] Adding column aperture_sum_61x106 to self.photometry_df
# [INFO] Adding column aperture_sum_62x106 to self.photometry_df
# [INFO] Adding column aperture_sum_63x106 to self.photometry_df
# [INFO] Adding column aperture_sum_64x106 to self.photometry_df
# [INFO] Adding column aperture_sum_65x106 to self.photometry_df
# [INFO] Adding column aperture_sum_66x106 to self.photometry_df
# [INFO] Adding column aperture_sum_67x106 to self.photometry_df
# [INFO] Adding column aperture_sum_68x106 to self.photometry_df
# [INFO] Adding column aperture_sum_69x106 to self.photometry_df
# [INFO] Adding column aperture_sum_70x106 to self.photometry_df
# [INFO] Adding column aperture_sum_71x106 to self.photometry_df
# [INFO] Adding column aperture_sum_72x106 to self.photometry_df
# [INFO] Adding column aperture_sum_73x106 to self.photometry_df
# [INFO] Adding column aperture_sum_74x106 to self.photometry_df
# [INFO] Adding column aperture_sum_75x106 to self.photometry_df
# [INFO] Adding column aperture_sum_76x106 to self.photometry_df
# [INFO] Adding column aperture_sum_77x106 to self.photometry_df
# [INFO] Adding column aperture_sum_78x106 to self.photometry_df
# [INFO] Adding column aperture_sum_79x106 to self.photometry_df
# [INFO] Adding column aperture_sum_80x106 to self.photometry_df
# [INFO] Adding column aperture_sum_61x107 to self.photometry_df
# [INFO] Adding column aperture_sum_62x107 to self.photometry_df
# [INFO] Adding column aperture_sum_63x107 to self.photometry_df
# [INFO] Adding column aperture_sum_64x107 to self.photometry_df
# [INFO] Adding column aperture_sum_65x107 to self.photometry_df
# [INFO] Adding column aperture_sum_66x107 to self.photometry_df
# [INFO] Adding column aperture_sum_67x107 to self.photometry_df
# [INFO] Adding column aperture_sum_68x107 to self.photometry_df
# [INFO] Adding column aperture_sum_69x107 to self.photometry_df
# [INFO] Adding column aperture_sum_70x107 to self.photometry_df
# [INFO] Adding column aperture_sum_71x107 to self.photometry_df
# [INFO] Adding column aperture_sum_72x107 to self.photometry_df
# [INFO] Adding column aperture_sum_73x107 to self.photometry_df
# [INFO] Adding column aperture_sum_74x107 to self.photometry_df
# [INFO] Adding column aperture_sum_75x107 to self.photometry_df
# [INFO] Adding column aperture_sum_76x107 to self.photometry_df
# [INFO] Adding column aperture_sum_77x107 to self.photometry_df
# [INFO] Adding column aperture_sum_78x107 to self.photometry_df
# [INFO] Adding column aperture_sum_79x107 to self.photometry_df
# [INFO] Adding column aperture_sum_80x107 to self.photometry_df
# [INFO] Adding column aperture_sum_61x108 to self.photometry_df
# [INFO] Adding column aperture_sum_62x108 to self.photometry_df
# [INFO] Adding column aperture_sum_63x108 to self.photometry_df
# [INFO] Adding column aperture_sum_64x108 to self.photometry_df
# [INFO] Adding column aperture_sum_65x108 to self.photometry_df
# [INFO] Adding column aperture_sum_66x108 to self.photometry_df
# [INFO] Adding column aperture_sum_67x108 to self.photometry_df
# [INFO] Adding column aperture_sum_68x108 to self.photometry_df
# [INFO] Adding column aperture_sum_69x108 to self.photometry_df
# [INFO] Adding column aperture_sum_70x108 to self.photometry_df
# [INFO] Adding column aperture_sum_71x108 to self.photometry_df
# [INFO] Adding column aperture_sum_72x108 to self.photometry_df
# [INFO] Adding column aperture_sum_73x108 to self.photometry_df
# [INFO] Adding column aperture_sum_74x108 to self.photometry_df
# [INFO] Adding column aperture_sum_75x108 to self.photometry_df
# [INFO] Adding column aperture_sum_76x108 to self.photometry_df
# [INFO] Adding column aperture_sum_77x108 to self.photometry_df
# [INFO] Adding column aperture_sum_78x108 to self.photometry_df
# [INFO] Adding column aperture_sum_79x108 to self.photometry_df
# [INFO] Adding column aperture_sum_80x108 to self.photometry_df
# [INFO] Adding column aperture_sum_61x109 to self.photometry_df
# [INFO] Adding column aperture_sum_62x109 to self.photometry_df
# [INFO] Adding column aperture_sum_63x109 to self.photometry_df
# [INFO] Adding column aperture_sum_64x109 to self.photometry_df
# [INFO] Adding column aperture_sum_65x109 to self.photometry_df
# [INFO] Adding column aperture_sum_66x109 to self.photometry_df
# [INFO] Adding column aperture_sum_67x109 to self.photometry_df
# [INFO] Adding column aperture_sum_68x109 to self.photometry_df
# [INFO] Adding column aperture_sum_69x109 to self.photometry_df
# [INFO] Adding column aperture_sum_70x109 to self.photometry_df
# [INFO] Adding column aperture_sum_71x109 to self.photometry_df
# [INFO] Adding column aperture_sum_72x109 to self.photometry_df
# [INFO] Adding column aperture_sum_73x109 to self.photometry_df
# [INFO] Adding column aperture_sum_74x109 to self.photometry_df
# [INFO] Adding column aperture_sum_75x109 to self.photometry_df
# [INFO] Adding column aperture_sum_76x109 to self.photometry_df
# [INFO] Adding column aperture_sum_77x109 to self.photometry_df
# [INFO] Adding column aperture_sum_78x109 to self.photometry_df
# [INFO] Adding column aperture_sum_79x109 to self.photometry_df
# [INFO] Adding column aperture_sum_80x109 to self.photometry_df
# [INFO] Adding column aperture_sum_61x110 to self.photometry_df
# [INFO] Adding column aperture_sum_62x110 to self.photometry_df
# [INFO] Adding column aperture_sum_63x110 to self.photometry_df
# [INFO] Adding column aperture_sum_64x110 to self.photometry_df
# [INFO] Adding column aperture_sum_65x110 to self.photometry_df
# [INFO] Adding column aperture_sum_66x110 to self.photometry_df
# [INFO] Adding column aperture_sum_67x110 to self.photometry_df
# [INFO] Adding column aperture_sum_68x110 to self.photometry_df
# [INFO] Adding column aperture_sum_69x110 to self.photometry_df
# [INFO] Adding column aperture_sum_70x110 to self.photometry_df
# [INFO] Adding column aperture_sum_71x110 to self.photometry_df
# [INFO] Adding column aperture_sum_72x110 to self.photometry_df
# [INFO] Adding column aperture_sum_73x110 to self.photometry_df
# [INFO] Adding column aperture_sum_74x110 to self.photometry_df
# [INFO] Adding column aperture_sum_75x110 to self.photometry_df
# [INFO] Adding column aperture_sum_76x110 to self.photometry_df
# [INFO] Adding column aperture_sum_77x110 to self.photometry_df
# [INFO] Adding column aperture_sum_78x110 to self.photometry_df
# [INFO] Adding column aperture_sum_79x110 to self.photometry_df
# [INFO] Adding column aperture_sum_80x110 to self.photometry_df

# %%
planet_fine_photometry_df = planet.photometry_df.copy()

# %%
fine_snr_lightcurves = create_raw_lc_stddev(planet)
fine_min_snr = fine_snr_lightcurves[fine_snr_lightcurves.argmin()]
fine_min_snr_colname = planet.photometry_df.columns[fine_snr_lightcurves.argmin()]
fine_min_snr_flux = planet.normed_photometry_df[fine_min_snr_colname]
fine_min_snr_uncs = planet.normed_uncertainty_df[fine_min_snr_colname]
fine_temp = fine_min_snr_colname.split('_')[-1].split('x')
fine_min_snr_aper_width, fine_min_snr_aper_height = np.int32(fine_temp)

# %%
info_message(f'Fine Aperture Photometry Resulted in {fine_min_snr:0.0f}ppm with '
             f'{fine_min_snr_aper_width}x{fine_min_snr_aper_height} aperture size; '
             f'with median uncertainties of {np.median(fine_min_snr_uncs)*1e6:0.0f} ppm')
# Out:
# [INFO] Fine Aperture Photometry Resulted in 3742ppm with 71x104 aperture size; with median uncertainties of 143 ppm

# %%
data_df = pd.DataFrame()
data_df['flux'] = fine_min_snr_flux.values
data_df['unc'] = fine_min_snr_uncs.values
data_df['times'] = planet.times
idx_fwd = planet.idx_fwd
idx_rev = planet.idx_rev
# data_df.sort_values('times', inplace=True)
# data_df = data_df.reset_index()
# data_df.drop(['index'], axis=1, inplace=True)
data_df
# Out:
#         flux       unc         times
# 0   0.999002  0.000140  59486.596360
# 1   1.007721  0.000145  59486.597239
# 2   0.999088  0.000140  59486.598119
# 3   1.008748  0.000145  59486.598998
# 4   1.005698  0.000141  59486.599878
# ..       ...       ...           ...
# 89  0.999746  0.000145  59486.750144
# 90  1.001206  0.000141  59486.751024
# 91  1.000084  0.000145  59486.751903
# 92  1.000436  0.000140  59486.752783
# 93  0.999493  0.000145  59486.753663
#
# [94 rows x 3 columns]

# %%
# Compute a limb-darkened light curve using starry
t = data_df['times']
u = []
flux = data_df['flux']
yerr = data_df['unc']
# Note: the `eval` is needed because this is using Theano in
# the background

plt.errorbar(t[idx_fwd], flux[idx_fwd], yerr[idx_fwd], fmt='o', color="b")
plt.errorbar(t[idx_rev], flux[idx_rev], yerr[idx_rev], fmt='o', color="r")
plt.axhline(1.0, ls='--', color='C1')
plt.ylabel("relative flux")
plt.xlabel("time [days]")
plt.xlim(t.min(), t.max());
