# %%
import time
start_time = time.time()
import os
HOME = os.environ['HOME']
# os.chdir(f'{HOME}/desktop/LTT1445_fits_files/Test/Tes2/Tes3/Tes4')
# os.chdir(f'{HOME}/desktop/LTT1445_fits_files/Test/Tes2/Tes3')                    #2nd epoch
os.chdir(f'{HOME}/desktop/LTT1445_fits_files/Test/Tes2')                         #1st epoch

# %%
import joblib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.stats import mad_std, sigma_clip
import warnings
warnings.filterwarnings("ignore")

import exoplanet as xo

from arctor3 import Arctor, info_message

# %%
transit1 = [0,512,300,513]
transit2 = [0,512,178,220]
transit3 = [0,512,150,180]

# %%
def instantiate_arctor(planet_name, transit, data_dir, working_dir, file_type):
    planet = Arctor(
        planet_name=planet_name,
        data_dir=data_dir,
        working_dir=working_dir,
        file_type=file_type)

    joblib_filename = f'{planet_name}_savedict.joblib.save'
    joblib_filename = f'{working_dir}/{joblib_filename}'
    if os.path.exists(joblib_filename):
        info_message('Loading Data from Save File')
        planet.load_data(joblib_filename)
    else:
        info_message('Loading New Data Object')
        planet.load_data(transit)

    return planet

def create_raw_lc_stddev(planet):
    ppm = 1e6
    phot_vals = planet.photometry_df
    lc_std_rev = phot_vals.iloc[planet.idx_rev].std(axis=0)                
    lc_std_fwd = phot_vals.iloc[planet.idx_fwd].std(axis=0)                

    lc_med_rev = np.median(phot_vals.iloc[planet.idx_rev], axis=0)
    lc_med_fwd = np.median(phot_vals.iloc[planet.idx_rev], axis=0)

    lc_std = np.mean([lc_std_rev, lc_std_fwd], axis=0)
    lc_med = np.mean([lc_med_rev, lc_med_fwd], axis=0)

    return lc_std / lc_med * ppm

# %%
plot_verbose = False
save_now = False
planet_name = 'PlanetName'
file_type = 'flt.fits'

HOME = os.environ['HOME']
# base_dir = os.path.join(HOME, 'path', 'to', 'base')
# data_dir = os.path.join(base_dir, 'path', 'to', 'data')
# data_dir = os.path.join(data_dir, 'HST', 'FLTs')
# working_dir = os.path.join(base_dir, 'path', 'to', 'savefiles')
# base_dir = os.path.join(HOME, 'desktop', 'LTT1445_fits_files', 'Test', 'Tes2', 'Tes3')        #2nd epoch
base_dir = os.path.join(HOME, 'desktop', 'LTT1445_fits_files', 'Test', 'Tes2')                #1st epoch
data_dir = os.path.join(base_dir)
data_dir = os.path.join(data_dir)
working_dir = os.path.join(base_dir)

# %%
transit = transit2
planet = instantiate_arctor(planet_name, transit, data_dir, working_dir, file_type)
print(planet)
# Out:
# [INFO] Initializing Instance of the `Arctor` Object
# [INFO] Loading New Data Object
# [INFO] Loading Fits Files
# 100%|██████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 266.32it/s]
# [INFO] Creating New Flux/Error/Time Attributes
# 100%|███████████████████████████████████████████████████████████████████████████████████| 94/94 [00:01<00:00, 73.27it/s]
# [INFO] Found 94 flt.fits files
# <arctor3.Arctor object at 0x7fa590701bb0>

# %%
planet.clean_cosmic_rays()
planet.calibration_trace_location()
planet.identify_trace_direction()
planet.simple_phots()
planet.center_all_traces()
planet.fit_trace_slopes()
planet.compute_sky_background(subpixels=32)
planet.compute_columnwise_sky_background()
# Out:
# [INFO] Flagging Cosmic Rays using `Temporal Simple` Technique
# 100%|███████████████████████████████████████████████████████████████████████████████████| 42/42 [00:02<00:00, 19.04it/s]
# [INFO] Cosmic Ray Mask Creation Took 2.2123422622680664 seconds
# None
# [INFO] Calibration the Median Trace Location
# [INFO] Cubic Spline Interpolating the Median Trace Location
# [INFO] Calibration the Per Image Trace Location
# 100%|█████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 1483.63it/s]
# [INFO] Identifying Trace Direction per Image
# 100%|█████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 2176.31it/s]
# [INFO] Computing the Center of the Trace
# 100%|███████████████████████████████████████████████████████████████████████████████████| 94/94 [00:18<00:00,  5.10it/s]
# [INFO] Fitting a slope to the Center of the Trace
# 100%|███████████████████████████████████████████████████████████████████████████████████| 94/94 [00:20<00:00,  4.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 514.32it/s]

# %%
# Set up the list of aperture widths and heights to search
min_aper_width = 1
max_aper_width = 100
min_aper_height = 1
max_aper_height = 100

aper_widths = np.arange(min_aper_width, max_aper_width + 2, 5)
aper_heights = np.arange(min_aper_height, max_aper_height + 2, 5)

# %%
planet.do_multi_phot(aper_widths, aper_heights)
print("code took", (time.time()-start_time)/60, "minutes")
# Out:
# [INFO] Beginning Multi-Aperture Photometry
# [INFO] Creating Apertures
# 100%|███████████████████████████████████████████████████████████████████████████████████| 94/94 [00:01<00:00, 89.97it/s]
# [INFO] Configuing Photoutils.Aperture_Photometry
# [INFO] Computing Aperture Photometry per Image
# [INFO] Aperture Photometry per Image took 162.55467677116394 seconds for 41454 apertures.
# [INFO] Restructuring Aperture Photometry into DataFrames
#     aperture_sum_1x1  aperture_sum_6x1  aperture_sum_11x1  aperture_sum_16x1  \
# 0       1.907436e+06      1.907436e+06       1.907436e+06       1.907436e+06
# 1       1.923224e+06      1.923224e+06       1.923224e+06       1.923224e+06
# 2       1.909215e+06      1.909215e+06       1.909215e+06       1.909215e+06
# 3       1.972413e+06      1.972413e+06       1.972413e+06       1.972413e+06
# 4       1.913325e+06      1.913325e+06       1.913325e+06       1.913325e+06
# ..               ...               ...                ...                ...
# 89      1.763445e+06      1.763445e+06       1.763445e+06       1.763445e+06
# 90      1.770986e+06      1.770986e+06       1.770986e+06       1.770986e+06
# 91      1.792031e+06      1.792031e+06       1.792031e+06       1.792031e+06
# 92      1.789276e+06      1.789276e+06       1.789276e+06       1.789276e+06
# 93      1.750209e+06      1.750209e+06       1.750209e+06       1.750209e+06
#
#     aperture_sum_21x1  aperture_sum_26x1  aperture_sum_31x1  \
# 0        1.907436e+06       1.907436e+06       1.907436e+06
# 1        1.923224e+06       1.923224e+06       1.923224e+06
# 2        1.909215e+06       1.909215e+06       1.909215e+06
# 3        1.972413e+06       1.972413e+06       1.972413e+06
# 4        1.913325e+06       1.913325e+06       1.913325e+06
# ..                ...                ...                ...
# 89       1.763445e+06       1.763445e+06       1.763445e+06
# 90       1.770986e+06       1.770986e+06       1.770986e+06
# 91       1.792031e+06       1.792031e+06       1.792031e+06
# 92       1.789276e+06       1.789276e+06       1.789276e+06
# 93       1.750209e+06       1.750209e+06       1.750209e+06
#
#     aperture_sum_36x1  aperture_sum_41x1  aperture_sum_46x1  ...  \
# 0        1.907436e+06       1.907436e+06       1.907436e+06  ...
# 1        1.923224e+06       1.923224e+06       1.923224e+06  ...
# 2        1.909215e+06       1.909215e+06       1.909215e+06  ...
# 3        1.972413e+06       1.972413e+06       1.972413e+06  ...
# 4        1.913325e+06       1.913325e+06       1.913325e+06  ...
# ..                ...                ...                ...  ...
# 89       1.763445e+06       1.763445e+06       1.763445e+06  ...
# 90       1.770986e+06       1.770986e+06       1.770986e+06  ...
# 91       1.792031e+06       1.792031e+06       1.792031e+06  ...
# 92       1.789276e+06       1.789276e+06       1.789276e+06  ...
# 93       1.750209e+06       1.750209e+06       1.750209e+06  ...
#
#     aperture_sum_66x101  aperture_sum_71x101  aperture_sum_76x101  \
# 0          6.178013e+06         6.178013e+06         6.178013e+06
# 1          6.178879e+06         6.178879e+06         6.178879e+06
# 2          6.194332e+06         6.194332e+06         6.194332e+06
# 3          6.184256e+06         6.184256e+06         6.184256e+06
# 4          6.167186e+06         6.167186e+06         6.167186e+06
# ..                  ...                  ...                  ...
# 89         6.183069e+06         6.183069e+06         6.183069e+06
# 90         6.204967e+06         6.204967e+06         6.204967e+06
# 91         6.194842e+06         6.194842e+06         6.194842e+06
# 92         6.185746e+06         6.185746e+06         6.185746e+06
# 93         6.175317e+06         6.175317e+06         6.175317e+06
#
#     aperture_sum_81x101  aperture_sum_86x101  aperture_sum_91x101  \
# 0          6.178013e+06         6.178013e+06         6.178013e+06
# 1          6.178879e+06         6.178879e+06         6.178879e+06
# 2          6.194332e+06         6.194332e+06         6.194332e+06
# 3          6.184256e+06         6.184256e+06         6.184256e+06
# 4          6.167186e+06         6.167186e+06         6.167186e+06
# ..                  ...                  ...                  ...
# 89         6.183069e+06         6.183069e+06         6.183069e+06
# 90         6.204967e+06         6.204967e+06         6.204967e+06
# 91         6.194842e+06         6.194842e+06         6.194842e+06
# 92         6.185746e+06         6.185746e+06         6.185746e+06
# 93         6.175317e+06         6.175317e+06         6.175317e+06
#
#     aperture_sum_96x101  aperture_sum_101x101  xcenter     ycenter
# 0          6.178013e+06          6.178013e+06     21.0  351.956380
# 1          6.178879e+06          6.178879e+06     21.0  351.892356
# 2          6.194332e+06          6.194332e+06     21.0  351.923020
# 3          6.184256e+06          6.184256e+06     21.0  351.934959
# 4          6.167186e+06          6.167186e+06     21.0  351.932461
# ..                  ...                   ...      ...         ...
# 89         6.183069e+06          6.183069e+06     21.0  351.731910
# 90         6.204967e+06          6.204967e+06     21.0  351.710078
# 91         6.194842e+06          6.194842e+06     21.0  351.771439
# 92         6.185746e+06          6.185746e+06     21.0  351.758625
# 93         6.175317e+06          6.175317e+06     21.0  351.729823
#
# [94 rows x 443 columns]
# code took 3.6916707277297975 minutes

# %%
planet_coarse_photometry_df = planet.photometry_df.copy()
planet.photometry_df
# Out:
#     aperture_sum_1x1  aperture_sum_6x1  aperture_sum_11x1  aperture_sum_16x1  \
# 0       1.907436e+06      1.907436e+06       1.907436e+06       1.907436e+06
# 1       1.923224e+06      1.923224e+06       1.923224e+06       1.923224e+06
# 2       1.909215e+06      1.909215e+06       1.909215e+06       1.909215e+06
# 3       1.972413e+06      1.972413e+06       1.972413e+06       1.972413e+06
# 4       1.913325e+06      1.913325e+06       1.913325e+06       1.913325e+06
# ..               ...               ...                ...                ...
# 89      1.763445e+06      1.763445e+06       1.763445e+06       1.763445e+06
# 90      1.770986e+06      1.770986e+06       1.770986e+06       1.770986e+06
# 91      1.792031e+06      1.792031e+06       1.792031e+06       1.792031e+06
# 92      1.789276e+06      1.789276e+06       1.789276e+06       1.789276e+06
# 93      1.750209e+06      1.750209e+06       1.750209e+06       1.750209e+06
#
#     aperture_sum_21x1  aperture_sum_26x1  aperture_sum_31x1  \
# 0        1.907436e+06       1.907436e+06       1.907436e+06
# 1        1.923224e+06       1.923224e+06       1.923224e+06
# 2        1.909215e+06       1.909215e+06       1.909215e+06
# 3        1.972413e+06       1.972413e+06       1.972413e+06
# 4        1.913325e+06       1.913325e+06       1.913325e+06
# ..                ...                ...                ...
# 89       1.763445e+06       1.763445e+06       1.763445e+06
# 90       1.770986e+06       1.770986e+06       1.770986e+06
# 91       1.792031e+06       1.792031e+06       1.792031e+06
# 92       1.789276e+06       1.789276e+06       1.789276e+06
# 93       1.750209e+06       1.750209e+06       1.750209e+06
#
#     aperture_sum_36x1  aperture_sum_41x1  aperture_sum_46x1  ...  \
# 0        1.907436e+06       1.907436e+06       1.907436e+06  ...
# 1        1.923224e+06       1.923224e+06       1.923224e+06  ...
# 2        1.909215e+06       1.909215e+06       1.909215e+06  ...
# 3        1.972413e+06       1.972413e+06       1.972413e+06  ...
# 4        1.913325e+06       1.913325e+06       1.913325e+06  ...
# ..                ...                ...                ...  ...
# 89       1.763445e+06       1.763445e+06       1.763445e+06  ...
# 90       1.770986e+06       1.770986e+06       1.770986e+06  ...
# 91       1.792031e+06       1.792031e+06       1.792031e+06  ...
# 92       1.789276e+06       1.789276e+06       1.789276e+06  ...
# 93       1.750209e+06       1.750209e+06       1.750209e+06  ...
#
#     aperture_sum_56x101  aperture_sum_61x101  aperture_sum_66x101  \
# 0          6.178013e+06         6.178013e+06         6.178013e+06
# 1          6.178879e+06         6.178879e+06         6.178879e+06
# 2          6.194332e+06         6.194332e+06         6.194332e+06
# 3          6.184256e+06         6.184256e+06         6.184256e+06
# 4          6.167186e+06         6.167186e+06         6.167186e+06
# ..                  ...                  ...                  ...
# 89         6.183069e+06         6.183069e+06         6.183069e+06
# 90         6.204967e+06         6.204967e+06         6.204967e+06
# 91         6.194842e+06         6.194842e+06         6.194842e+06
# 92         6.185746e+06         6.185746e+06         6.185746e+06
# 93         6.175317e+06         6.175317e+06         6.175317e+06
#
#     aperture_sum_71x101  aperture_sum_76x101  aperture_sum_81x101  \
# 0          6.178013e+06         6.178013e+06         6.178013e+06
# 1          6.178879e+06         6.178879e+06         6.178879e+06
# 2          6.194332e+06         6.194332e+06         6.194332e+06
# 3          6.184256e+06         6.184256e+06         6.184256e+06
# 4          6.167186e+06         6.167186e+06         6.167186e+06
# ..                  ...                  ...                  ...
# 89         6.183069e+06         6.183069e+06         6.183069e+06
# 90         6.204967e+06         6.204967e+06         6.204967e+06
# 91         6.194842e+06         6.194842e+06         6.194842e+06
# 92         6.185746e+06         6.185746e+06         6.185746e+06
# 93         6.175317e+06         6.175317e+06         6.175317e+06
#
#     aperture_sum_86x101  aperture_sum_91x101  aperture_sum_96x101  \
# 0          6.178013e+06         6.178013e+06         6.178013e+06
# 1          6.178879e+06         6.178879e+06         6.178879e+06
# 2          6.194332e+06         6.194332e+06         6.194332e+06
# 3          6.184256e+06         6.184256e+06         6.184256e+06
# 4          6.167186e+06         6.167186e+06         6.167186e+06
# ..                  ...                  ...                  ...
# 89         6.183069e+06         6.183069e+06         6.183069e+06
# 90         6.204967e+06         6.204967e+06         6.204967e+06
# 91         6.194842e+06         6.194842e+06         6.194842e+06
# 92         6.185746e+06         6.185746e+06         6.185746e+06
# 93         6.175317e+06         6.175317e+06         6.175317e+06
#
#     aperture_sum_101x101
# 0           6.178013e+06
# 1           6.178879e+06
# 2           6.194332e+06
# 3           6.184256e+06
# 4           6.167186e+06
# ..                   ...
# 89          6.183069e+06
# 90          6.204967e+06
# 91          6.194842e+06
# 92          6.185746e+06
# 93          6.175317e+06
#
# [94 rows x 441 columns]

# %%
coarse_snr_lightcurves = create_raw_lc_stddev(planet)
coarse_min_snr = coarse_snr_lightcurves[coarse_snr_lightcurves.argmin()]
coarse_min_snr_colname = planet.photometry_df.columns[coarse_snr_lightcurves.argmin()]
coarse_min_snr_col = planet.normed_photometry_df[coarse_min_snr_colname]
coarse_temp = coarse_min_snr_colname.split('_')[-1].split('x')
coarse_min_snr_aper_width, coarse_min_snr_aper_height = np.int32(coarse_temp)

# %%
info_message(f'Coarse Aperture Photometry Resulted in {coarse_min_snr:0.0f}ppm with '
             f'{coarse_min_snr_aper_width}x{coarse_min_snr_aper_height} aperture size')
# Out:
# [INFO] Coarse Aperture Photometry Resulted in 1370ppm with 6x101 aperture size

# %%
fine_buffer = 10
fine_aper_widths = np.arange(coarse_min_snr_aper_width - fine_buffer,
                             coarse_min_snr_aper_width + fine_buffer)

fine_aper_heights = np.arange(coarse_min_snr_aper_height - fine_buffer,
                              coarse_min_snr_aper_height + fine_buffer)

# %%
planet.do_multi_phot(fine_aper_widths, fine_aper_heights)
# Out:
# [INFO] Beginning Multi-Aperture Photometry
# [INFO] Creating Apertures
# 100%|███████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 96.39it/s]
# [INFO] Configuing Photoutils.Aperture_Photometry
# [INFO] Computing Aperture Photometry per Image
# [INFO] Aperture Photometry per Image took 140.30365109443665 seconds for 37600 apertures.
# [INFO] Restructuring Aperture Photometry into DataFrames
#     aperture_sum_-4x91  aperture_sum_-3x91  aperture_sum_-2x91  \
# 0         5.583561e+06        5.730530e+06        5.878427e+06
# 1         5.586462e+06        5.732603e+06        5.880122e+06
# 2         5.602139e+06        5.748519e+06        5.895620e+06
# 3         5.590086e+06        5.737149e+06        5.885141e+06
# 4         5.577799e+06        5.723640e+06        5.869883e+06
# ..                 ...                 ...                 ...
# 89        5.587273e+06        5.734681e+06        5.882842e+06
# 90        5.610788e+06        5.758153e+06        5.905764e+06
# 91        5.602530e+06        5.750262e+06        5.897658e+06
# 92        5.595700e+06        5.742049e+06        5.888269e+06
# 93        5.581175e+06        5.728605e+06        5.876479e+06
#
#     aperture_sum_-1x91  aperture_sum_0x91  aperture_sum_1x91  \
# 0         6.025028e+06       6.100102e+06       6.172357e+06
# 1         6.027618e+06       6.101281e+06       6.174895e+06
# 2         6.041194e+06       6.116513e+06       6.188529e+06
# 3         6.033041e+06       6.106627e+06       6.180020e+06
# 4         6.014722e+06       6.089577e+06       6.161376e+06
# ..                 ...                ...                ...
# 89        6.030843e+06       6.104845e+06       6.178538e+06
# 90        6.051890e+06       6.127042e+06       6.198934e+06
# 91        6.045054e+06       6.117971e+06       6.190887e+06
# 92        6.032791e+06       6.107792e+06       6.179269e+06
# 93        6.024288e+06       6.097543e+06       6.170687e+06
#
#     aperture_sum_2x91  aperture_sum_3x91  aperture_sum_4x91  \
# 0        6.173812e+06       6.173812e+06       6.173812e+06
# 1        6.174918e+06       6.174918e+06       6.174918e+06
# 2        6.190193e+06       6.190194e+06       6.190194e+06
# 3        6.180113e+06       6.180113e+06       6.180113e+06
# 4        6.162964e+06       6.162964e+06       6.162964e+06
# ..                ...                ...                ...
# 89       6.178678e+06       6.178678e+06       6.178678e+06
# 90       6.200629e+06       6.200629e+06       6.200629e+06
# 91       6.190887e+06       6.190887e+06       6.190887e+06
# 92       6.181243e+06       6.181246e+06       6.181246e+06
# 93       6.170740e+06       6.170740e+06       6.170740e+06
#
#     aperture_sum_5x91  ...  aperture_sum_8x110  aperture_sum_9x110  \
# 0        6.173812e+06  ...        6.179752e+06        6.179752e+06
# 1        6.174918e+06  ...        6.180335e+06        6.180335e+06
# 2        6.190194e+06  ...        6.195946e+06        6.195946e+06
# 3        6.180113e+06  ...        6.185885e+06        6.185885e+06
# 4        6.162964e+06  ...        6.168997e+06        6.168997e+06
# ..                ...  ...                 ...                 ...
# 89       6.178678e+06  ...        6.184905e+06        6.184905e+06
# 90       6.200629e+06  ...        6.206758e+06        6.206758e+06
# 91       6.190887e+06  ...        6.196526e+06        6.196526e+06
# 92       6.181246e+06  ...        6.187993e+06        6.187993e+06
# 93       6.170740e+06  ...        6.177340e+06        6.177340e+06
#
#     aperture_sum_10x110  aperture_sum_11x110  aperture_sum_12x110  \
# 0          6.179752e+06         6.179752e+06         6.179752e+06
# 1          6.180335e+06         6.180335e+06         6.180335e+06
# 2          6.195946e+06         6.195946e+06         6.195946e+06
# 3          6.185885e+06         6.185885e+06         6.185885e+06
# 4          6.168997e+06         6.168997e+06         6.168997e+06
# ..                  ...                  ...                  ...
# 89         6.184905e+06         6.184905e+06         6.184905e+06
# 90         6.206758e+06         6.206758e+06         6.206758e+06
# 91         6.196526e+06         6.196526e+06         6.196526e+06
# 92         6.187993e+06         6.187993e+06         6.187993e+06
# 93         6.177340e+06         6.177340e+06         6.177340e+06
#
#     aperture_sum_13x110  aperture_sum_14x110  aperture_sum_15x110  xcenter  \
# 0          6.179752e+06         6.179752e+06         6.179752e+06     21.0
# 1          6.180335e+06         6.180335e+06         6.180335e+06     21.0
# 2          6.195946e+06         6.195946e+06         6.195946e+06     21.0
# 3          6.185885e+06         6.185885e+06         6.185885e+06     21.0
# 4          6.168997e+06         6.168997e+06         6.168997e+06     21.0
# ..                  ...                  ...                  ...      ...
# 89         6.184905e+06         6.184905e+06         6.184905e+06     21.0
# 90         6.206758e+06         6.206758e+06         6.206758e+06     21.0
# 91         6.196526e+06         6.196526e+06         6.196526e+06     21.0
# 92         6.187993e+06         6.187993e+06         6.187993e+06     21.0
# 93         6.177340e+06         6.177340e+06         6.177340e+06     21.0
#
#        ycenter
# 0   351.956380
# 1   351.892356
# 2   351.923020
# 3   351.934959
# 4   351.932461
# ..         ...
# 89  351.731910
# 90  351.710078
# 91  351.771439
# 92  351.758625
# 93  351.729823
#
# [94 rows x 402 columns]
# [INFO] Adding column aperture_sum_-4x91 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x91 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x91 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x91 to self.photometry_df
# [INFO] Adding column aperture_sum_0x91 to self.photometry_df
# [INFO] Adding column aperture_sum_2x91 to self.photometry_df
# [INFO] Adding column aperture_sum_3x91 to self.photometry_df
# [INFO] Adding column aperture_sum_4x91 to self.photometry_df
# [INFO] Adding column aperture_sum_5x91 to self.photometry_df
# [INFO] Adding column aperture_sum_7x91 to self.photometry_df
# [INFO] Adding column aperture_sum_8x91 to self.photometry_df
# [INFO] Adding column aperture_sum_9x91 to self.photometry_df
# [INFO] Adding column aperture_sum_10x91 to self.photometry_df
# [INFO] Adding column aperture_sum_12x91 to self.photometry_df
# [INFO] Adding column aperture_sum_13x91 to self.photometry_df
# [INFO] Adding column aperture_sum_14x91 to self.photometry_df
# [INFO] Adding column aperture_sum_15x91 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x92 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x92 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x92 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x92 to self.photometry_df
# [INFO] Adding column aperture_sum_0x92 to self.photometry_df
# [INFO] Adding column aperture_sum_1x92 to self.photometry_df
# [INFO] Adding column aperture_sum_2x92 to self.photometry_df
# [INFO] Adding column aperture_sum_3x92 to self.photometry_df
# [INFO] Adding column aperture_sum_4x92 to self.photometry_df
# [INFO] Adding column aperture_sum_5x92 to self.photometry_df
# [INFO] Adding column aperture_sum_6x92 to self.photometry_df
# [INFO] Adding column aperture_sum_7x92 to self.photometry_df
# [INFO] Adding column aperture_sum_8x92 to self.photometry_df
# [INFO] Adding column aperture_sum_9x92 to self.photometry_df
# [INFO] Adding column aperture_sum_10x92 to self.photometry_df
# [INFO] Adding column aperture_sum_11x92 to self.photometry_df
# [INFO] Adding column aperture_sum_12x92 to self.photometry_df
# [INFO] Adding column aperture_sum_13x92 to self.photometry_df
# [INFO] Adding column aperture_sum_14x92 to self.photometry_df
# [INFO] Adding column aperture_sum_15x92 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x93 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x93 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x93 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x93 to self.photometry_df
# [INFO] Adding column aperture_sum_0x93 to self.photometry_df
# [INFO] Adding column aperture_sum_1x93 to self.photometry_df
# [INFO] Adding column aperture_sum_2x93 to self.photometry_df
# [INFO] Adding column aperture_sum_3x93 to self.photometry_df
# [INFO] Adding column aperture_sum_4x93 to self.photometry_df
# [INFO] Adding column aperture_sum_5x93 to self.photometry_df
# [INFO] Adding column aperture_sum_6x93 to self.photometry_df
# [INFO] Adding column aperture_sum_7x93 to self.photometry_df
# [INFO] Adding column aperture_sum_8x93 to self.photometry_df
# [INFO] Adding column aperture_sum_9x93 to self.photometry_df
# [INFO] Adding column aperture_sum_10x93 to self.photometry_df
# [INFO] Adding column aperture_sum_11x93 to self.photometry_df
# [INFO] Adding column aperture_sum_12x93 to self.photometry_df
# [INFO] Adding column aperture_sum_13x93 to self.photometry_df
# [INFO] Adding column aperture_sum_14x93 to self.photometry_df
# [INFO] Adding column aperture_sum_15x93 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x94 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x94 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x94 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x94 to self.photometry_df
# [INFO] Adding column aperture_sum_0x94 to self.photometry_df
# [INFO] Adding column aperture_sum_1x94 to self.photometry_df
# [INFO] Adding column aperture_sum_2x94 to self.photometry_df
# [INFO] Adding column aperture_sum_3x94 to self.photometry_df
# [INFO] Adding column aperture_sum_4x94 to self.photometry_df
# [INFO] Adding column aperture_sum_5x94 to self.photometry_df
# [INFO] Adding column aperture_sum_6x94 to self.photometry_df
# [INFO] Adding column aperture_sum_7x94 to self.photometry_df
# [INFO] Adding column aperture_sum_8x94 to self.photometry_df
# [INFO] Adding column aperture_sum_9x94 to self.photometry_df
# [INFO] Adding column aperture_sum_10x94 to self.photometry_df
# [INFO] Adding column aperture_sum_11x94 to self.photometry_df
# [INFO] Adding column aperture_sum_12x94 to self.photometry_df
# [INFO] Adding column aperture_sum_13x94 to self.photometry_df
# [INFO] Adding column aperture_sum_14x94 to self.photometry_df
# [INFO] Adding column aperture_sum_15x94 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x95 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x95 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x95 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x95 to self.photometry_df
# [INFO] Adding column aperture_sum_0x95 to self.photometry_df
# [INFO] Adding column aperture_sum_1x95 to self.photometry_df
# [INFO] Adding column aperture_sum_2x95 to self.photometry_df
# [INFO] Adding column aperture_sum_3x95 to self.photometry_df
# [INFO] Adding column aperture_sum_4x95 to self.photometry_df
# [INFO] Adding column aperture_sum_5x95 to self.photometry_df
# [INFO] Adding column aperture_sum_6x95 to self.photometry_df
# [INFO] Adding column aperture_sum_7x95 to self.photometry_df
# [INFO] Adding column aperture_sum_8x95 to self.photometry_df
# [INFO] Adding column aperture_sum_9x95 to self.photometry_df
# [INFO] Adding column aperture_sum_10x95 to self.photometry_df
# [INFO] Adding column aperture_sum_11x95 to self.photometry_df
# [INFO] Adding column aperture_sum_12x95 to self.photometry_df
# [INFO] Adding column aperture_sum_13x95 to self.photometry_df
# [INFO] Adding column aperture_sum_14x95 to self.photometry_df
# [INFO] Adding column aperture_sum_15x95 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x96 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x96 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x96 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x96 to self.photometry_df
# [INFO] Adding column aperture_sum_0x96 to self.photometry_df
# [INFO] Adding column aperture_sum_2x96 to self.photometry_df
# [INFO] Adding column aperture_sum_3x96 to self.photometry_df
# [INFO] Adding column aperture_sum_4x96 to self.photometry_df
# [INFO] Adding column aperture_sum_5x96 to self.photometry_df
# [INFO] Adding column aperture_sum_7x96 to self.photometry_df
# [INFO] Adding column aperture_sum_8x96 to self.photometry_df
# [INFO] Adding column aperture_sum_9x96 to self.photometry_df
# [INFO] Adding column aperture_sum_10x96 to self.photometry_df
# [INFO] Adding column aperture_sum_12x96 to self.photometry_df
# [INFO] Adding column aperture_sum_13x96 to self.photometry_df
# [INFO] Adding column aperture_sum_14x96 to self.photometry_df
# [INFO] Adding column aperture_sum_15x96 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x97 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x97 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x97 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x97 to self.photometry_df
# [INFO] Adding column aperture_sum_0x97 to self.photometry_df
# [INFO] Adding column aperture_sum_1x97 to self.photometry_df
# [INFO] Adding column aperture_sum_2x97 to self.photometry_df
# [INFO] Adding column aperture_sum_3x97 to self.photometry_df
# [INFO] Adding column aperture_sum_4x97 to self.photometry_df
# [INFO] Adding column aperture_sum_5x97 to self.photometry_df
# [INFO] Adding column aperture_sum_6x97 to self.photometry_df
# [INFO] Adding column aperture_sum_7x97 to self.photometry_df
# [INFO] Adding column aperture_sum_8x97 to self.photometry_df
# [INFO] Adding column aperture_sum_9x97 to self.photometry_df
# [INFO] Adding column aperture_sum_10x97 to self.photometry_df
# [INFO] Adding column aperture_sum_11x97 to self.photometry_df
# [INFO] Adding column aperture_sum_12x97 to self.photometry_df
# [INFO] Adding column aperture_sum_13x97 to self.photometry_df
# [INFO] Adding column aperture_sum_14x97 to self.photometry_df
# [INFO] Adding column aperture_sum_15x97 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x98 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x98 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x98 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x98 to self.photometry_df
# [INFO] Adding column aperture_sum_0x98 to self.photometry_df
# [INFO] Adding column aperture_sum_1x98 to self.photometry_df
# [INFO] Adding column aperture_sum_2x98 to self.photometry_df
# [INFO] Adding column aperture_sum_3x98 to self.photometry_df
# [INFO] Adding column aperture_sum_4x98 to self.photometry_df
# [INFO] Adding column aperture_sum_5x98 to self.photometry_df
# [INFO] Adding column aperture_sum_6x98 to self.photometry_df
# [INFO] Adding column aperture_sum_7x98 to self.photometry_df
# [INFO] Adding column aperture_sum_8x98 to self.photometry_df
# [INFO] Adding column aperture_sum_9x98 to self.photometry_df
# [INFO] Adding column aperture_sum_10x98 to self.photometry_df
# [INFO] Adding column aperture_sum_11x98 to self.photometry_df
# [INFO] Adding column aperture_sum_12x98 to self.photometry_df
# [INFO] Adding column aperture_sum_13x98 to self.photometry_df
# [INFO] Adding column aperture_sum_14x98 to self.photometry_df
# [INFO] Adding column aperture_sum_15x98 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x99 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x99 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x99 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x99 to self.photometry_df
# [INFO] Adding column aperture_sum_0x99 to self.photometry_df
# [INFO] Adding column aperture_sum_1x99 to self.photometry_df
# [INFO] Adding column aperture_sum_2x99 to self.photometry_df
# [INFO] Adding column aperture_sum_3x99 to self.photometry_df
# [INFO] Adding column aperture_sum_4x99 to self.photometry_df
# [INFO] Adding column aperture_sum_5x99 to self.photometry_df
# [INFO] Adding column aperture_sum_6x99 to self.photometry_df
# [INFO] Adding column aperture_sum_7x99 to self.photometry_df
# [INFO] Adding column aperture_sum_8x99 to self.photometry_df
# [INFO] Adding column aperture_sum_9x99 to self.photometry_df
# [INFO] Adding column aperture_sum_10x99 to self.photometry_df
# [INFO] Adding column aperture_sum_11x99 to self.photometry_df
# [INFO] Adding column aperture_sum_12x99 to self.photometry_df
# [INFO] Adding column aperture_sum_13x99 to self.photometry_df
# [INFO] Adding column aperture_sum_14x99 to self.photometry_df
# [INFO] Adding column aperture_sum_15x99 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x100 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x100 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x100 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x100 to self.photometry_df
# [INFO] Adding column aperture_sum_0x100 to self.photometry_df
# [INFO] Adding column aperture_sum_1x100 to self.photometry_df
# [INFO] Adding column aperture_sum_2x100 to self.photometry_df
# [INFO] Adding column aperture_sum_3x100 to self.photometry_df
# [INFO] Adding column aperture_sum_4x100 to self.photometry_df
# [INFO] Adding column aperture_sum_5x100 to self.photometry_df
# [INFO] Adding column aperture_sum_6x100 to self.photometry_df
# [INFO] Adding column aperture_sum_7x100 to self.photometry_df
# [INFO] Adding column aperture_sum_8x100 to self.photometry_df
# [INFO] Adding column aperture_sum_9x100 to self.photometry_df
# [INFO] Adding column aperture_sum_10x100 to self.photometry_df
# [INFO] Adding column aperture_sum_11x100 to self.photometry_df
# [INFO] Adding column aperture_sum_12x100 to self.photometry_df
# [INFO] Adding column aperture_sum_13x100 to self.photometry_df
# [INFO] Adding column aperture_sum_14x100 to self.photometry_df
# [INFO] Adding column aperture_sum_15x100 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x101 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x101 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x101 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x101 to self.photometry_df
# [INFO] Adding column aperture_sum_0x101 to self.photometry_df
# [INFO] Adding column aperture_sum_2x101 to self.photometry_df
# [INFO] Adding column aperture_sum_3x101 to self.photometry_df
# [INFO] Adding column aperture_sum_4x101 to self.photometry_df
# [INFO] Adding column aperture_sum_5x101 to self.photometry_df
# [INFO] Adding column aperture_sum_7x101 to self.photometry_df
# [INFO] Adding column aperture_sum_8x101 to self.photometry_df
# [INFO] Adding column aperture_sum_9x101 to self.photometry_df
# [INFO] Adding column aperture_sum_10x101 to self.photometry_df
# [INFO] Adding column aperture_sum_12x101 to self.photometry_df
# [INFO] Adding column aperture_sum_13x101 to self.photometry_df
# [INFO] Adding column aperture_sum_14x101 to self.photometry_df
# [INFO] Adding column aperture_sum_15x101 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x102 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x102 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x102 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x102 to self.photometry_df
# [INFO] Adding column aperture_sum_0x102 to self.photometry_df
# [INFO] Adding column aperture_sum_1x102 to self.photometry_df
# [INFO] Adding column aperture_sum_2x102 to self.photometry_df
# [INFO] Adding column aperture_sum_3x102 to self.photometry_df
# [INFO] Adding column aperture_sum_4x102 to self.photometry_df
# [INFO] Adding column aperture_sum_5x102 to self.photometry_df
# [INFO] Adding column aperture_sum_6x102 to self.photometry_df
# [INFO] Adding column aperture_sum_7x102 to self.photometry_df
# [INFO] Adding column aperture_sum_8x102 to self.photometry_df
# [INFO] Adding column aperture_sum_9x102 to self.photometry_df
# [INFO] Adding column aperture_sum_10x102 to self.photometry_df
# [INFO] Adding column aperture_sum_11x102 to self.photometry_df
# [INFO] Adding column aperture_sum_12x102 to self.photometry_df
# [INFO] Adding column aperture_sum_13x102 to self.photometry_df
# [INFO] Adding column aperture_sum_14x102 to self.photometry_df
# [INFO] Adding column aperture_sum_15x102 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x103 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x103 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x103 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x103 to self.photometry_df
# [INFO] Adding column aperture_sum_0x103 to self.photometry_df
# [INFO] Adding column aperture_sum_1x103 to self.photometry_df
# [INFO] Adding column aperture_sum_2x103 to self.photometry_df
# [INFO] Adding column aperture_sum_3x103 to self.photometry_df
# [INFO] Adding column aperture_sum_4x103 to self.photometry_df
# [INFO] Adding column aperture_sum_5x103 to self.photometry_df
# [INFO] Adding column aperture_sum_6x103 to self.photometry_df
# [INFO] Adding column aperture_sum_7x103 to self.photometry_df
# [INFO] Adding column aperture_sum_8x103 to self.photometry_df
# [INFO] Adding column aperture_sum_9x103 to self.photometry_df
# [INFO] Adding column aperture_sum_10x103 to self.photometry_df
# [INFO] Adding column aperture_sum_11x103 to self.photometry_df
# [INFO] Adding column aperture_sum_12x103 to self.photometry_df
# [INFO] Adding column aperture_sum_13x103 to self.photometry_df
# [INFO] Adding column aperture_sum_14x103 to self.photometry_df
# [INFO] Adding column aperture_sum_15x103 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x104 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x104 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x104 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x104 to self.photometry_df
# [INFO] Adding column aperture_sum_0x104 to self.photometry_df
# [INFO] Adding column aperture_sum_1x104 to self.photometry_df
# [INFO] Adding column aperture_sum_2x104 to self.photometry_df
# [INFO] Adding column aperture_sum_3x104 to self.photometry_df
# [INFO] Adding column aperture_sum_4x104 to self.photometry_df
# [INFO] Adding column aperture_sum_5x104 to self.photometry_df
# [INFO] Adding column aperture_sum_6x104 to self.photometry_df
# [INFO] Adding column aperture_sum_7x104 to self.photometry_df
# [INFO] Adding column aperture_sum_8x104 to self.photometry_df
# [INFO] Adding column aperture_sum_9x104 to self.photometry_df
# [INFO] Adding column aperture_sum_10x104 to self.photometry_df
# [INFO] Adding column aperture_sum_11x104 to self.photometry_df
# [INFO] Adding column aperture_sum_12x104 to self.photometry_df
# [INFO] Adding column aperture_sum_13x104 to self.photometry_df
# [INFO] Adding column aperture_sum_14x104 to self.photometry_df
# [INFO] Adding column aperture_sum_15x104 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x105 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x105 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x105 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x105 to self.photometry_df
# [INFO] Adding column aperture_sum_0x105 to self.photometry_df
# [INFO] Adding column aperture_sum_1x105 to self.photometry_df
# [INFO] Adding column aperture_sum_2x105 to self.photometry_df
# [INFO] Adding column aperture_sum_3x105 to self.photometry_df
# [INFO] Adding column aperture_sum_4x105 to self.photometry_df
# [INFO] Adding column aperture_sum_5x105 to self.photometry_df
# [INFO] Adding column aperture_sum_6x105 to self.photometry_df
# [INFO] Adding column aperture_sum_7x105 to self.photometry_df
# [INFO] Adding column aperture_sum_8x105 to self.photometry_df
# [INFO] Adding column aperture_sum_9x105 to self.photometry_df
# [INFO] Adding column aperture_sum_10x105 to self.photometry_df
# [INFO] Adding column aperture_sum_11x105 to self.photometry_df
# [INFO] Adding column aperture_sum_12x105 to self.photometry_df
# [INFO] Adding column aperture_sum_13x105 to self.photometry_df
# [INFO] Adding column aperture_sum_14x105 to self.photometry_df
# [INFO] Adding column aperture_sum_15x105 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x106 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x106 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x106 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x106 to self.photometry_df
# [INFO] Adding column aperture_sum_0x106 to self.photometry_df
# [INFO] Adding column aperture_sum_1x106 to self.photometry_df
# [INFO] Adding column aperture_sum_2x106 to self.photometry_df
# [INFO] Adding column aperture_sum_3x106 to self.photometry_df
# [INFO] Adding column aperture_sum_4x106 to self.photometry_df
# [INFO] Adding column aperture_sum_5x106 to self.photometry_df
# [INFO] Adding column aperture_sum_6x106 to self.photometry_df
# [INFO] Adding column aperture_sum_7x106 to self.photometry_df
# [INFO] Adding column aperture_sum_8x106 to self.photometry_df
# [INFO] Adding column aperture_sum_9x106 to self.photometry_df
# [INFO] Adding column aperture_sum_10x106 to self.photometry_df
# [INFO] Adding column aperture_sum_11x106 to self.photometry_df
# [INFO] Adding column aperture_sum_12x106 to self.photometry_df
# [INFO] Adding column aperture_sum_13x106 to self.photometry_df
# [INFO] Adding column aperture_sum_14x106 to self.photometry_df
# [INFO] Adding column aperture_sum_15x106 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x107 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x107 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x107 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x107 to self.photometry_df
# [INFO] Adding column aperture_sum_0x107 to self.photometry_df
# [INFO] Adding column aperture_sum_1x107 to self.photometry_df
# [INFO] Adding column aperture_sum_2x107 to self.photometry_df
# [INFO] Adding column aperture_sum_3x107 to self.photometry_df
# [INFO] Adding column aperture_sum_4x107 to self.photometry_df
# [INFO] Adding column aperture_sum_5x107 to self.photometry_df
# [INFO] Adding column aperture_sum_6x107 to self.photometry_df
# [INFO] Adding column aperture_sum_7x107 to self.photometry_df
# [INFO] Adding column aperture_sum_8x107 to self.photometry_df
# [INFO] Adding column aperture_sum_9x107 to self.photometry_df
# [INFO] Adding column aperture_sum_10x107 to self.photometry_df
# [INFO] Adding column aperture_sum_11x107 to self.photometry_df
# [INFO] Adding column aperture_sum_12x107 to self.photometry_df
# [INFO] Adding column aperture_sum_13x107 to self.photometry_df
# [INFO] Adding column aperture_sum_14x107 to self.photometry_df
# [INFO] Adding column aperture_sum_15x107 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x108 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x108 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x108 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x108 to self.photometry_df
# [INFO] Adding column aperture_sum_0x108 to self.photometry_df
# [INFO] Adding column aperture_sum_1x108 to self.photometry_df
# [INFO] Adding column aperture_sum_2x108 to self.photometry_df
# [INFO] Adding column aperture_sum_3x108 to self.photometry_df
# [INFO] Adding column aperture_sum_4x108 to self.photometry_df
# [INFO] Adding column aperture_sum_5x108 to self.photometry_df
# [INFO] Adding column aperture_sum_6x108 to self.photometry_df
# [INFO] Adding column aperture_sum_7x108 to self.photometry_df
# [INFO] Adding column aperture_sum_8x108 to self.photometry_df
# [INFO] Adding column aperture_sum_9x108 to self.photometry_df
# [INFO] Adding column aperture_sum_10x108 to self.photometry_df
# [INFO] Adding column aperture_sum_11x108 to self.photometry_df
# [INFO] Adding column aperture_sum_12x108 to self.photometry_df
# [INFO] Adding column aperture_sum_13x108 to self.photometry_df
# [INFO] Adding column aperture_sum_14x108 to self.photometry_df
# [INFO] Adding column aperture_sum_15x108 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x109 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x109 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x109 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x109 to self.photometry_df
# [INFO] Adding column aperture_sum_0x109 to self.photometry_df
# [INFO] Adding column aperture_sum_1x109 to self.photometry_df
# [INFO] Adding column aperture_sum_2x109 to self.photometry_df
# [INFO] Adding column aperture_sum_3x109 to self.photometry_df
# [INFO] Adding column aperture_sum_4x109 to self.photometry_df
# [INFO] Adding column aperture_sum_5x109 to self.photometry_df
# [INFO] Adding column aperture_sum_6x109 to self.photometry_df
# [INFO] Adding column aperture_sum_7x109 to self.photometry_df
# [INFO] Adding column aperture_sum_8x109 to self.photometry_df
# [INFO] Adding column aperture_sum_9x109 to self.photometry_df
# [INFO] Adding column aperture_sum_10x109 to self.photometry_df
# [INFO] Adding column aperture_sum_11x109 to self.photometry_df
# [INFO] Adding column aperture_sum_12x109 to self.photometry_df
# [INFO] Adding column aperture_sum_13x109 to self.photometry_df
# [INFO] Adding column aperture_sum_14x109 to self.photometry_df
# [INFO] Adding column aperture_sum_15x109 to self.photometry_df
# [INFO] Adding column aperture_sum_-4x110 to self.photometry_df
# [INFO] Adding column aperture_sum_-3x110 to self.photometry_df
# [INFO] Adding column aperture_sum_-2x110 to self.photometry_df
# [INFO] Adding column aperture_sum_-1x110 to self.photometry_df
# [INFO] Adding column aperture_sum_0x110 to self.photometry_df
# [INFO] Adding column aperture_sum_1x110 to self.photometry_df
# [INFO] Adding column aperture_sum_2x110 to self.photometry_df
# [INFO] Adding column aperture_sum_3x110 to self.photometry_df
# [INFO] Adding column aperture_sum_4x110 to self.photometry_df
# [INFO] Adding column aperture_sum_5x110 to self.photometry_df
# [INFO] Adding column aperture_sum_6x110 to self.photometry_df
# [INFO] Adding column aperture_sum_7x110 to self.photometry_df
# [INFO] Adding column aperture_sum_8x110 to self.photometry_df
# [INFO] Adding column aperture_sum_9x110 to self.photometry_df
# [INFO] Adding column aperture_sum_10x110 to self.photometry_df
# [INFO] Adding column aperture_sum_11x110 to self.photometry_df
# [INFO] Adding column aperture_sum_12x110 to self.photometry_df
# [INFO] Adding column aperture_sum_13x110 to self.photometry_df
# [INFO] Adding column aperture_sum_14x110 to self.photometry_df
# [INFO] Adding column aperture_sum_15x110 to self.photometry_df

# %%
planet_fine_photometry_df = planet.photometry_df.copy()

# %%
fine_snr_lightcurves = create_raw_lc_stddev(planet)
fine_min_snr = fine_snr_lightcurves[fine_snr_lightcurves.argmin()]
fine_min_snr_colname = planet.photometry_df.columns[fine_snr_lightcurves.argmin()]
fine_min_snr_flux = planet.normed_photometry_df[fine_min_snr_colname]
fine_min_snr_uncs = planet.normed_uncertainty_df[fine_min_snr_colname]
fine_temp = fine_min_snr_colname.split('_')[-1].split('x')
fine_min_snr_aper_width, fine_min_snr_aper_height = np.int32(fine_temp)

# %%
info_message(f'Fine Aperture Photometry Resulted in {fine_min_snr:0.0f}ppm with '
             f'{fine_min_snr_aper_width}x{fine_min_snr_aper_height} aperture size; '
             f'with median uncertainties of {np.median(fine_min_snr_uncs)*1e6:0.0f} ppm')
# Out:
# [INFO] Fine Aperture Photometry Resulted in 1368ppm with 2x108 aperture size; with median uncertainties of 402 ppm

# %%
data_df = pd.DataFrame()
data_df['flux'] = fine_min_snr_flux.values
data_df['unc'] = fine_min_snr_uncs.values
data_df['times'] = planet.times
idx_fwd = planet.idx_fwd
idx_rev = planet.idx_rev
# data_df.sort_values('times', inplace=True)
# data_df = data_df.reset_index()
# data_df.drop(['index'], axis=1, inplace=True)
data_df
# Out:
#         flux       unc         times
# 0   0.998697  0.000402  59483.485144
# 1   0.999227  0.000402  59483.486024
# 2   1.001315  0.000402  59483.486904
# 3   1.000116  0.000402  59483.487783
# 4   0.996952  0.000401  59483.488663
# ..       ...       ...           ...
# 89  0.999951  0.000402  59483.639577
# 90  1.003053  0.000403  59483.640457
# 91  1.001834  0.000402  59483.641336
# 92  1.000000  0.000402  59483.642216
# 93  0.998732  0.000402  59483.643095
#
# [94 rows x 3 columns]

# %%
# Compute a limb-darkened light curve using starry
t = data_df['times']
u = []
flux = data_df['flux']
yerr = data_df['unc']
# Note: the `eval` is needed because this is using Theano in
# the background

plt.errorbar(t[idx_fwd], flux[idx_fwd], yerr[idx_fwd], fmt='o', color="b")
plt.errorbar(t[idx_rev], flux[idx_rev], yerr[idx_rev], fmt='o', color="r")
plt.axhline(1.0, ls='--', color='C1')
plt.ylabel("relative flux")
plt.xlabel("time [days]")
plt.xlim(t.min(), t.max());

# %%
fluxppm = (data_df['flux'] - 1)*1e6

# %%
plt.errorbar(t[idx_fwd], fluxppm[idx_fwd], yerr[idx_fwd], fmt='o', color="b")
plt.errorbar(t[idx_rev], fluxppm[idx_rev], yerr[idx_rev], fmt='o', color="r")
plt.axhline(1.0, ls='--', color='C1')
plt.ylabel("flux (ppm)")
plt.xlabel("time [days]")
plt.xlim(t.min(), t.max());

# %%
print("code took", (time.time()-start_time)/60, "minutes")
# Out:
# code took 6.241707718372345 minutes
